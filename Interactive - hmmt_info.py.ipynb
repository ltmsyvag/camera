# %% [markdown]
# Connected to camera (Python 3.12.9)

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    # cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    for key, val in list(cam.attributes.items())[:5]: # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(key, "||",val)
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    #  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    # cam.close() # the good'ol close. 用 with 语句时完全用不着
    # cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    # cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident
    for key, val in list(cam.get_all_attribute_values().items())[:3]: # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        print(key, "||",val)
    # cam.get_all_attributes() # 等价于前述的 cam.attributes
# Out:
# False
# sensor_mode || DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0)
# readout_speed || DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0)
# readout_direction || DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0)
# colortype || DCAMAttribute(name='COLORTYPE', kind=enum, id=4325664, min=1, max=1, unit=0)
# bit_per_channel || DCAMAttribute(name='BIT PER CHANNEL', kind=int, id=4325680, min=12, max=16, unit=0)
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# sensor_mode || 1
# readout_speed || 2
# readout_direction || 1

# %%
from codetiming import Timer
t = Timer("t", logger=None)
N = 10
for _ in range(N):
    with t:
        with DCAM.DCAMCamera() as cam: pass
print(Timer.timers.mean("t"))
print(Timer.timers.stdev("t"))
# Out:
# 5.4680106900050305
# 0.010874813249342577

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    # cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes
    for key, val in list(cam.attributes.items())[:5]: # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(key, "||",val)
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    #  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    # cam.close() # the good'ol close. 用 with 语句时完全用不着
    # cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    # cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for key, val in list(cam.get_all_attribute_values().items())[:3]: # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        print(key, "||",val)
    # cam.get_all_attributes() # 等价于前述的 cam.attributes
    # print(cam.get)
# Out:
# False
# sensor_mode || DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0)
# readout_speed || DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0)
# readout_direction || DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0)
# colortype || DCAMAttribute(name='COLORTYPE', kind=enum, id=4325664, min=1, max=1, unit=0)
# bit_per_channel || DCAMAttribute(name='BIT PER CHANNEL', kind=int, id=4325680, min=12, max=16, unit=0)
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# sensor_mode || 1
# readout_speed || 2
# readout_direction || 1

# %%
attrDict
# Out:
# Dictionary('binning': DCAMAttribute(name='BINNING', kind=enum, id=4198672, min=1, max=4, unit=0)
# 'bit_per_channel': DCAMAttribute(name='BIT PER CHANNEL', kind=int, id=4325680, min=12, max=16, unit=0)
# 'buffer_framebytes': DCAMAttribute(name='BUFFER FRAMEBYTES', kind=int, id=4326208, min=2, max=18874368, unit=0)
# 'buffer_pixel_type': DCAMAttribute(name='BUFFER PIXEL TYPE', kind=enum, id=4326240, min=1, max=3, unit=0)
# 'buffer_rowbytes': DCAMAttribute(name='BUFFER ROWBYTES', kind=int, id=4326192, min=2, max=8192, unit=0)
# 'buffer_top_offset_bytes': DCAMAttribute(name='BUFFER TOP OFFSET BYTES', kind=int, id=4326224, min=0, max=0, unit=0)
# 'capture_mode': DCAMAttribute(name='CAPTURE MODE', kind=enum, id=3671056, min=1, max=1, unit=0)
# 'colortype': DCAMAttribute(name='COLORTYPE', kind=enum, id=4325664, min=1, max=1, unit=0)
# 'conversion_factor_coeff': DCAMAttribute(name='CONVERSION FACTOR COEFF', kind=float, id=16769040, min=0.0, max=255.99, unit=0)
# 'conversion_factor_offset': DCAMAttribute(name='CONVERSION FACTOR OFFSET', kind=float, id=16769056, min=-65535.0, max=65535.0, unit=0)
# 'defect_correct_mode': DCAMAttribute(name='DEFECT CORRECT MODE', kind=enum, id=4653072, min=1, max=2, unit=0)
# 'exposure_time': DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 'frame_stamp_producer': DCAMAttribute(name='FRAME STAMP PRODUCER', kind=enum, id=4262432, min=5, max=5, unit=0)
# 'framebundle_frame_step_bytes': DCAMAttribute(name='FRAMEBUNDLE FRAME STEP BYTES', kind=int, id=4329536, min=18874368, max=18874368, unit=0)
# 'framebundle_mode': DCAMAttribute(name='FRAMEBUNDLE MODE', kind=enum, id=4329488, min=1, max=2, unit=0)
# 'framebundle_number': DCAMAttribute(name='FRAMEBUNDLE NUMBER', kind=int, id=4329504, min=2, max=2, unit=0)
# 'framebundle_rowbytes': DCAMAttribute(name='FRAMEBUNDLE ROWBYTES', kind=int, id=4329520, min=8192, max=8192, unit=0)
# 'hot_pixel_correct_level': DCAMAttribute(name='HOT PIXEL CORRECT LEVEL', kind=enum, id=4653104, min=1, max=3, unit=0)
# 'image_camera_stamp': DCAMAttribute(name='IMAGE CAMERA STAMP', kind=int, id=4326144, min=0, max=65535, unit=0)
# 'image_detector_pixel_height': DCAMAttribute(name='IMAGE DETECTOR PIXEL HEIGHT', kind=float, id=4327456, min=4.6000000000000005, max=4.6000000000000005, unit=7)
# 'image_detector_pixel_num_horz': DCAMAttribute(name='IMAGE DETECTOR PIXEL NUM HORZ', kind=int, id=4327472, min=4096, max=4096, unit=0)
# 'image_detector_pixel_num_vert': DCAMAttribute(name='IMAGE DETECTOR PIXEL NUM VERT', kind=int, id=4327488, min=2304, max=2304, unit=0)
# 'image_detector_pixel_width': DCAMAttribute(name='IMAGE DETECTOR PIXEL WIDTH', kind=float, id=4327440, min=4.6000000000000005, max=4.6000000000000005, unit=7)
# 'image_framebytes': DCAMAttribute(name='IMAGE FRAMEBYTES', kind=int, id=4325952, min=2, max=18874368, unit=0)
# 'image_height': DCAMAttribute(name='IMAGE HEIGHT', kind=int, id=4325920, min=4, max=2304, unit=0)
# 'image_pixel_type': DCAMAttribute(name='IMAGE PIXEL TYPE', kind=enum, id=4326000, min=1, max=3, unit=0)
# 'image_rowbytes': DCAMAttribute(name='IMAGE ROWBYTES', kind=int, id=4325936, min=2, max=8192, unit=0)
# 'image_top_offset_bytes': DCAMAttribute(name='IMAGE TOP OFFSET BYTES', kind=int, id=4325968, min=0, max=0, unit=0)
# 'image_width': DCAMAttribute(name='IMAGE WIDTH', kind=int, id=4325904, min=4, max=4096, unit=0)
# 'intensity_lut_mode': DCAMAttribute(name='INTENSITY LUT MODE', kind=enum, id=3671312, min=1, max=2, unit=0)
# 'intensity_lut_page': DCAMAttribute(name='INTENSITY LUT PAGE', kind=enum, id=3671328, min=1, max=1, unit=0)
# 'internal_frame_interval': DCAMAttribute(name='INTERNAL FRAME INTERVAL', kind=float, id=4208672, min=0.0564984, max=1800.0, unit=1)
# 'internal_frame_rate': DCAMAttribute(name='INTERNAL FRAME RATE', kind=float, id=4208656, min=0.0005555555555555556, max=17.69961627231922, unit=5)
# 'internal_line_interval': DCAMAttribute(name='INTERNAL LINE INTERVAL', kind=float, id=4208720, min=7.2e-06, max=7.2e-06, unit=1)
# 'internal_line_speed': DCAMAttribute(name='INTERNAL LINE SPEED', kind=float, id=4208704, min=0.638888888888889, max=0.638888888888889, unit=4)
# 'master_pulse_burst_times': DCAMAttribute(name='MASTER PULSE BURST TIMES', kind=int, id=1966160, min=1, max=65535, unit=0)
# 'master_pulse_interval': DCAMAttribute(name='MASTER PULSE INTERVAL', kind=float, id=1966144, min=4.9999999999999996e-06, max=10.0, unit=1)
# 'master_pulse_mode': DCAMAttribute(name='MASTER PULSE MODE', kind=enum, id=1966112, min=1, max=3, unit=0)
# 'master_pulse_trigger_source': DCAMAttribute(name='MASTER PULSE TRIGGER SOURCE', kind=enum, id=1966128, min=1, max=2, unit=0)
# 'number_of_output_trigger_connector': DCAMAttribute(name='NUMBER OF OUTPUT TRIGGER CONNECTOR', kind=int, id=1835024, min=3, max=3, unit=0)
# 'output_trigger_active[0]': DCAMAttribute(name='OUTPUT TRIGGER ACTIVE[0]', kind=enum, id=1835312, min=1, max=1, unit=0)
# 'output_trigger_delay[0]': DCAMAttribute(name='OUTPUT TRIGGER DELAY[0]', kind=float, id=1835328, min=0.0, max=10.0, unit=1)
# 'output_trigger_kind[0]': DCAMAttribute(name='OUTPUT TRIGGER KIND[0]', kind=enum, id=1835360, min=1, max=6, unit=0)
# 'output_trigger_period[0]': DCAMAttribute(name='OUTPUT TRIGGER PERIOD[0]', kind=float, id=1835344, min=1e-06, max=10.0, unit=1)
# 'output_trigger_polarity[0]': DCAMAttribute(name='OUTPUT TRIGGER POLARITY[0]', kind=enum, id=1835296, min=1, max=2, unit=0)
# 'output_trigger_pre_hsync_count': DCAMAttribute(name='OUTPUT TRIGGER PRE HSYNC COUNT', kind=int, id=1835408, min=0, max=4607, unit=0)
# 'output_trigger_source[0]': DCAMAttribute(name='OUTPUT TRIGGER SOURCE[0]', kind=enum, id=1835280, min=2, max=6, unit=0)
# 'readout_direction': DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0)
# 'readout_speed': DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0)
# 'record_fixed_bytes_per_file': DCAMAttribute(name='RECORD FIXED BYTES PER FILE', kind=int, id=4326416, min=256, max=256, unit=0)
# 'record_fixed_bytes_per_frame': DCAMAttribute(name='RECORD FIXED BYTES PER FRAME', kind=int, id=4326448, min=0, max=18874416, unit=0)
# 'record_fixed_bytes_per_session': DCAMAttribute(name='RECORD FIXED BYTES PER SESSION', kind=int, id=4326432, min=0, max=1016, unit=0)
# 'sensor_cooler_status': DCAMAttribute(name='SENSOR COOLER STATUS', kind=enum, id=2097984, min=1, max=3, unit=0)
# 'sensor_mode': DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0)
# 'sensor_temperature': DCAMAttribute(name='SENSOR TEMPERATURE', kind=float, id=2097936, min=-50.0, max=100.0, unit=2)
# 'subarray_hpos': DCAMAttribute(name='SUBARRAY HPOS', kind=int, id=4202768, min=0, max=4092, unit=0)
# 'subarray_hsize': DCAMAttribute(name='SUBARRAY HSIZE', kind=int, id=4202784, min=4, max=4096, unit=0)
# 'subarray_mode': DCAMAttribute(name='SUBARRAY MODE', kind=enum, id=4202832, min=1, max=2, unit=0)
# 'subarray_vpos': DCAMAttribute(name='SUBARRAY VPOS', kind=int, id=4202800, min=0, max=2300, unit=0)
# 'subarray_vsize': DCAMAttribute(name='SUBARRAY VSIZE', kind=int, id=4202816, min=4, max=2304, unit=0)
# 'system_alive': DCAMAttribute(name='SYSTEM ALIVE', kind=enum, id=16711696, min=1, max=2, unit=0)
# 'time_stamp_producer': DCAMAttribute(name='TIME STAMP PRODUCER', kind=enum, id=4262416, min=5, max=5, unit=0)
# 'timing_cyclic_trigger_period': DCAMAttribute(name='TIMING CYCLIC TRIGGER PERIOD', kind=float, id=4206624, min=0.0, max=0.0, unit=1)
# 'timing_exposure': DCAMAttribute(name='TIMING EXPOSURE', kind=enum, id=4206688, min=3, max=3, unit=0)
# 'timing_global_exposure_delay': DCAMAttribute(name='TIMING GLOBAL EXPOSURE DELAY', kind=float, id=4206736, min=0.0, max=0.008344800000000001, unit=1)
# 'timing_invalid_exposure_period': DCAMAttribute(name='TIMING INVALID EXPOSURE PERIOD', kind=float, id=4206704, min=0.0, max=2.88e-05, unit=1)
# 'timing_min_trigger_blanking': DCAMAttribute(name='TIMING MIN TRIGGER BLANKING', kind=float, id=4206640, min=0.0, max=0.0, unit=1)
# 'timing_min_trigger_interval': DCAMAttribute(name='TIMING MIN TRIGGER INTERVAL', kind=float, id=4206672, min=0.0, max=0.0, unit=1)
# 'timing_readout_time': DCAMAttribute(name='TIMING READOUT TIME', kind=float, id=4206608, min=0.0, max=0.0, unit=1)
# 'trigger_active': DCAMAttribute(name='TRIGGER ACTIVE', kind=enum, id=1048864, min=1, max=3, unit=0)
# 'trigger_connector': DCAMAttribute(name='TRIGGER CONNECTOR', kind=enum, id=1049136, min=2, max=2, unit=0)
# 'trigger_delay': DCAMAttribute(name='TRIGGER DELAY', kind=float, id=1049184, min=0.0, max=10.0, unit=1)
# 'trigger_global_exposure': DCAMAttribute(name='TRIGGER GLOBAL EXPOSURE', kind=enum, id=2032384, min=3, max=5, unit=0)
# 'trigger_mode': DCAMAttribute(name='TRIGGER MODE', kind=enum, id=1049104, min=1, max=6, unit=0)
# 'trigger_polarity': DCAMAttribute(name='TRIGGER POLARITY', kind=enum, id=1049120, min=1, max=2, unit=0)
# 'trigger_source': DCAMAttribute(name='TRIGGER SOURCE', kind=enum, id=1048848, min=1, max=4, unit=0)
# 'trigger_times': DCAMAttribute(name='TRIGGER TIMES', kind=int, id=1049152, min=1, max=10000, unit=0))

# %%
type(attrDict)
# Out:
# pylablib.core.utils.dictionary.Dictionary

# %%
list(attrDict)
# Out:
# ['sensor_mode',
#  'readout_speed',
#  'readout_direction',
#  'colortype',
#  'bit_per_channel',
#  'trigger_source',
#  'trigger_mode',
#  'trigger_active',
#  'trigger_global_exposure',
#  'trigger_polarity',
#  'trigger_connector',
#  'trigger_times',
#  'trigger_delay',
#  'sensor_temperature',
#  'sensor_cooler_status',
#  'exposure_time',
#  'defect_correct_mode',
#  'hot_pixel_correct_level',
#  'binning',
#  'subarray_hpos',
#  'subarray_hsize',
#  'subarray_vpos',
#  'subarray_vsize',
#  'subarray_mode',
#  'capture_mode',
#  'intensity_lut_mode',
#  'intensity_lut_page',
#  'timing_readout_time',
#  'timing_cyclic_trigger_period',
#  'timing_min_trigger_blanking',
#  'timing_min_trigger_interval',
#  'timing_global_exposure_delay',
#  'timing_exposure',
#  'timing_invalid_exposure_period',
#  'internal_frame_rate',
#  'internal_frame_interval',
#  'internal_line_speed',
#  'internal_line_interval',
#  'framebundle_mode',
#  'framebundle_number',
#  'framebundle_rowbytes',
#  'framebundle_frame_step_bytes',
#  'image_width',
#  'image_height',
#  'image_rowbytes',
#  'image_framebytes',
#  'image_top_offset_bytes',
#  'image_pixel_type',
#  'image_camera_stamp',
#  'buffer_rowbytes',
#  'buffer_framebytes',
#  'buffer_top_offset_bytes',
#  'buffer_pixel_type',
#  'record_fixed_bytes_per_file',
#  'record_fixed_bytes_per_session',
#  'record_fixed_bytes_per_frame',
#  'number_of_output_trigger_connector',
#  'output_trigger_source[0]',
#  'output_trigger_polarity[0]',
#  'output_trigger_active[0]',
#  'output_trigger_delay[0]',
#  'output_trigger_period[0]',
#  'output_trigger_kind[0]',
#  'output_trigger_pre_hsync_count',
#  'master_pulse_mode',
#  'master_pulse_trigger_source',
#  'master_pulse_interval',
#  'master_pulse_burst_times',
#  'system_alive',
#  'conversion_factor_coeff',
#  'conversion_factor_offset',
#  'image_detector_pixel_width',
#  'image_detector_pixel_height',
#  'image_detector_pixel_num_horz',
#  'image_detector_pixel_num_vert',
#  'time_stamp_producer',
#  'frame_stamp_producer']

# %%
list(attrDict.keys())
# Out:
# ['sensor_mode',
#  'readout_speed',
#  'readout_direction',
#  'colortype',
#  'bit_per_channel',
#  'trigger_source',
#  'trigger_mode',
#  'trigger_active',
#  'trigger_global_exposure',
#  'trigger_polarity',
#  'trigger_connector',
#  'trigger_times',
#  'trigger_delay',
#  'sensor_temperature',
#  'sensor_cooler_status',
#  'exposure_time',
#  'defect_correct_mode',
#  'hot_pixel_correct_level',
#  'binning',
#  'subarray_hpos',
#  'subarray_hsize',
#  'subarray_vpos',
#  'subarray_vsize',
#  'subarray_mode',
#  'capture_mode',
#  'intensity_lut_mode',
#  'intensity_lut_page',
#  'timing_readout_time',
#  'timing_cyclic_trigger_period',
#  'timing_min_trigger_blanking',
#  'timing_min_trigger_interval',
#  'timing_global_exposure_delay',
#  'timing_exposure',
#  'timing_invalid_exposure_period',
#  'internal_frame_rate',
#  'internal_frame_interval',
#  'internal_line_speed',
#  'internal_line_interval',
#  'framebundle_mode',
#  'framebundle_number',
#  'framebundle_rowbytes',
#  'framebundle_frame_step_bytes',
#  'image_width',
#  'image_height',
#  'image_rowbytes',
#  'image_framebytes',
#  'image_top_offset_bytes',
#  'image_pixel_type',
#  'image_camera_stamp',
#  'buffer_rowbytes',
#  'buffer_framebytes',
#  'buffer_top_offset_bytes',
#  'buffer_pixel_type',
#  'record_fixed_bytes_per_file',
#  'record_fixed_bytes_per_session',
#  'record_fixed_bytes_per_frame',
#  'number_of_output_trigger_connector',
#  'output_trigger_source[0]',
#  'output_trigger_polarity[0]',
#  'output_trigger_active[0]',
#  'output_trigger_delay[0]',
#  'output_trigger_period[0]',
#  'output_trigger_kind[0]',
#  'output_trigger_pre_hsync_count',
#  'master_pulse_mode',
#  'master_pulse_trigger_source',
#  'master_pulse_interval',
#  'master_pulse_burst_times',
#  'system_alive',
#  'conversion_factor_coeff',
#  'conversion_factor_offset',
#  'image_detector_pixel_width',
#  'image_detector_pixel_height',
#  'image_detector_pixel_num_horz',
#  'image_detector_pixel_num_vert',
#  'time_stamp_producer',
#  'frame_stamp_producer']

# %%
dir(attrDict)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_dict',
#  '_attach_node',
#  '_case_normalization',
#  '_clear_root',
#  '_data',
#  '_deep_copy',
#  '_dfs_pattern',
#  '_fast_build_branch_pointer',
#  '_get_branch',
#  '_get_entry',
#  '_get_root',
#  '_get_valid_subpath',
#  '_insert_branch',
#  '_is_branch',
#  '_is_empty',
#  '_iterbranches',
#  '_make_similar_dict',
#  '_map_root',
#  '_normalize_path',
#  '_normalize_path_entry',
#  '_replace_root',
#  'add_entry',
#  'as_dict',
#  'as_dictionary',
#  'as_json',
#  'as_pandas',
#  'asdict',
#  'branch_copy',
#  'branch_pointer',
#  'collect',
#  'copy',
#  'del_entry',
#  'detach',
#  'diff',
#  'diff_flatdict',
#  'filter_self',
#  'find_intersection',
#  'from_json',
#  'get',
#  'get_entry',
#  'get_matching_paths',
#  'get_matching_subtree',
#  'get_max_prefix',
#  'get_path',
#  'has_entry',
#  'is_branch_path',
#  'is_dictionary',
#  'is_leaf_path',
#  'items',
#  'iteritems',
#  'iterkeys',
#  'iternodes',
#  'itervalues',
#  'keys',
#  'map_self',
#  'merge',
#  'nodes',
#  'paths',
#  'pop',
#  'ptr',
#  'setdefault',
#  'size',
#  'update',
#  'updated',
#  'values',
#  'viewitems',
#  'viewkeys',
#  'viewvalues']

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    # cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 
    list(cam.attributes.items())[:3]: # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    #  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    # cam.close() # the good'ol close. 用 with 语句时完全用不着
    # cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    # cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for key, val in list(cam.get_all_attribute_values().items())[:3]: # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        print(key, "||",val)
    # cam.get_all_attributes() # 等价于前述的 cam.attributes
    # print(cam.get)
# Out:
#   Cell In[9], line 12
#     list(cam.attributes.items())[:3]: # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
#                                       ^
# SyntaxError: invalid syntax

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    # cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 
    list(cam.attributes.items())[:3] # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    #  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    # cam.close() # the good'ol close. 用 with 语句时完全用不着
    # cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    # cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for key, val in list(cam.get_all_attribute_values().items())[:3]: # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        print(key, "||",val)
    # cam.get_all_attributes() # 等价于前述的 cam.attributes
    # print(cam.get)
# Out:
# False
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# sensor_mode || 1
# readout_speed || 2
# readout_direction || 1

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    # cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 
    print(list(cam.attributes.items())[:3]) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    #  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    # cam.close() # the good'ol close. 用 with 语句时完全用不着
    # cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    # cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for key, val in list(cam.get_all_attribute_values().items())[:3]: # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        print(key, "||",val)
    # cam.get_all_attributes() # 等价于前述的 cam.attributes
    # print(cam.get)
# Out:
# False
# [('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0)), ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0)), ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))]
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# sensor_mode || 1
# readout_speed || 2
# readout_direction || 1

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    # cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    #  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    # cam.close() # the good'ol close. 用 with 语句时完全用不着
    # cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    # cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for key, val in list(cam.get_all_attribute_values().items())[:3]: # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        print(key, "||",val)
    # cam.get_all_attributes() # 等价于前述的 cam.attributes
    # print(cam.get)
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# sensor_mode || 1
# readout_speed || 2
# readout_direction || 1

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values().items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    ## print(cam.get)
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# ('sensor_mode', 1)
# ('readout_speed', 2)
# ('readout_direction', 1)

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values().items()): print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    ## print(cam.get)
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# ('sensor_mode', 1)
# ('readout_speed', 2)
# ('readout_direction', 1)
# ('colortype', 1)
# ('bit_per_channel', 16)
# ('trigger_source', 1)
# ('trigger_mode', 1)
# ('trigger_active', 1)
# ('trigger_global_exposure', 3)
# ('trigger_polarity', 1)
# ('trigger_connector', 2)
# ('trigger_times', 1)
# ('trigger_delay', 0.0)
# ('sensor_temperature', -20.0)
# ('sensor_cooler_status', 2)
# ('exposure_time', 0.0082944)
# ('defect_correct_mode', 2)
# ('hot_pixel_correct_level', 1)
# ('binning', 1)
# ('subarray_hpos', 0)
# ('subarray_hsize', 4096)
# ('subarray_vpos', 0)
# ('subarray_vsize', 2304)
# ('subarray_mode', 1)
# ('capture_mode', 1)
# ('intensity_lut_mode', 1)
# ('intensity_lut_page', 1)
# ('timing_readout_time', 0.0564984)
# ('timing_cyclic_trigger_period', 0.0)
# ('timing_min_trigger_blanking', 0.0)
# ('timing_min_trigger_interval', 0.0564984)
# ('timing_global_exposure_delay', 2.88e-05)
# ('timing_exposure', 3)
# ('timing_invalid_exposure_period', 2.88e-05)
# ('internal_frame_rate', 17.69961627231922)
# ('internal_frame_interval', 0.0564984)
# ('internal_line_speed', 0.638888888888889)
# ('internal_line_interval', 7.2e-06)
# ('framebundle_mode', 1)
# ('framebundle_number', 2)
# ('framebundle_rowbytes', 8192)
# ('framebundle_frame_step_bytes', 18874368)
# ('image_width', 4096)
# ('image_height', 2304)
# ('image_rowbytes', 8192)
# ('image_framebytes', 18874368)
# ('image_top_offset_bytes', 0)
# ('image_pixel_type', 2)
# ('image_camera_stamp', 0)
# ('buffer_rowbytes', 8192)
# ('buffer_framebytes', 18874368)
# ('buffer_top_offset_bytes', 0)
# ('buffer_pixel_type', 2)
# ('record_fixed_bytes_per_file', 256)
# ('record_fixed_bytes_per_session', 800)
# ('record_fixed_bytes_per_frame', 18874416)
# ('number_of_output_trigger_connector', 3)
# ('output_trigger_source[0]', 2)
# ('output_trigger_polarity[0]', 1)
# ('output_trigger_active[0]', 1)
# ('output_trigger_delay[0]', 0.0)
# ('output_trigger_period[0]', 0.0009999999999999998)
# ('output_trigger_kind[0]', 1)
# ('output_trigger_pre_hsync_count', 0)
# ('master_pulse_mode', 1)
# ('master_pulse_trigger_source', 1)
# ('master_pulse_interval', 0.1)
# ('master_pulse_burst_times', 1)
# ('system_alive', 2)
# ('conversion_factor_coeff', 0.1)
# ('conversion_factor_offset', 200.0)
# ('image_detector_pixel_width', 4.6000000000000005)
# ('image_detector_pixel_height', 4.6000000000000005)
# ('image_detector_pixel_num_horz', 4096)
# ('image_detector_pixel_num_vert', 2304)
# ('time_stamp_producer', 5)
# ('frame_stamp_producer', 5)

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items()): print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    ## print(cam.get)
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ('colortype', 'B/W')
# ('bit_per_channel', 16)
# ('trigger_source', 'INTERNAL')
# ('trigger_mode', 'NORMAL')
# ('trigger_active', 'EDGE')
# ('trigger_global_exposure', 'DELAYED')
# ('trigger_polarity', 'NEGATIVE')
# ('trigger_connector', 'BNC')
# ('trigger_times', 1)
# ('trigger_delay', 0.0)
# ('sensor_temperature', -20.0)
# ('sensor_cooler_status', 'READY')
# ('exposure_time', 0.0082944)
# ('defect_correct_mode', 'ON')
# ('hot_pixel_correct_level', 'STANDARD')
# ('binning', '1x1')
# ('subarray_hpos', 0)
# ('subarray_hsize', 4096)
# ('subarray_vpos', 0)
# ('subarray_vsize', 2304)
# ('subarray_mode', 'OFF')
# ('capture_mode', 'NORMAL DATA')
# ('intensity_lut_mode', 'THROUGH')
# ('intensity_lut_page', '1')
# ('timing_readout_time', 0.0564984)
# ('timing_cyclic_trigger_period', 0.0)
# ('timing_min_trigger_blanking', 0.0)
# ('timing_min_trigger_interval', 0.0564984)
# ('timing_global_exposure_delay', 2.88e-05)
# ('timing_exposure', 'ROLLING')
# ('timing_invalid_exposure_period', 2.88e-05)
# ('internal_frame_rate', 17.69961627231922)
# ('internal_frame_interval', 0.0564984)
# ('internal_line_speed', 0.638888888888889)
# ('internal_line_interval', 7.2e-06)
# ('framebundle_mode', 'OFF')
# ('framebundle_number', 2)
# ('framebundle_rowbytes', 8192)
# ('framebundle_frame_step_bytes', 18874368)
# ('image_width', 4096)
# ('image_height', 2304)
# ('image_rowbytes', 8192)
# ('image_framebytes', 18874368)
# ('image_top_offset_bytes', 0)
# ('image_pixel_type', 'MONO16')
# ('image_camera_stamp', 0)
# ('buffer_rowbytes', 8192)
# ('buffer_framebytes', 18874368)
# ('buffer_top_offset_bytes', 0)
# ('buffer_pixel_type', 'MONO16')
# ('record_fixed_bytes_per_file', 256)
# ('record_fixed_bytes_per_session', 800)
# ('record_fixed_bytes_per_frame', 18874416)
# ('number_of_output_trigger_connector', 3)
# ('output_trigger_source[0]', 'READOUT END')
# ('output_trigger_polarity[0]', 'NEGATIVE')
# ('output_trigger_active[0]', 'EDGE')
# ('output_trigger_delay[0]', 0.0)
# ('output_trigger_period[0]', 0.0009999999999999998)
# ('output_trigger_kind[0]', 'LOW')
# ('output_trigger_pre_hsync_count', 0)
# ('master_pulse_mode', 'CONTINUOUS')
# ('master_pulse_trigger_source', 'EXTERNAL')
# ('master_pulse_interval', 0.1)
# ('master_pulse_burst_times', 1)
# ('system_alive', 'ONLINE')
# ('conversion_factor_coeff', 0.1)
# ('conversion_factor_offset', 200.0)
# ('image_detector_pixel_width', 4.6000000000000005)
# ('image_detector_pixel_height', 4.6000000000000005)
# ('image_detector_pixel_num_horz', 4096)
# ('image_detector_pixel_num_vert', 2304)
# ('time_stamp_producer', 'IMAGING DEVICE')
# ('frame_stamp_producer', 'IMAGING DEVICE')

# %%
attrDict
# Out:
# Dictionary('binning': DCAMAttribute(name='BINNING', kind=enum, id=4198672, min=1, max=4, unit=0)
# 'bit_per_channel': DCAMAttribute(name='BIT PER CHANNEL', kind=int, id=4325680, min=12, max=16, unit=0)
# 'buffer_framebytes': DCAMAttribute(name='BUFFER FRAMEBYTES', kind=int, id=4326208, min=2, max=18874368, unit=0)
# 'buffer_pixel_type': DCAMAttribute(name='BUFFER PIXEL TYPE', kind=enum, id=4326240, min=1, max=3, unit=0)
# 'buffer_rowbytes': DCAMAttribute(name='BUFFER ROWBYTES', kind=int, id=4326192, min=2, max=8192, unit=0)
# 'buffer_top_offset_bytes': DCAMAttribute(name='BUFFER TOP OFFSET BYTES', kind=int, id=4326224, min=0, max=0, unit=0)
# 'capture_mode': DCAMAttribute(name='CAPTURE MODE', kind=enum, id=3671056, min=1, max=1, unit=0)
# 'colortype': DCAMAttribute(name='COLORTYPE', kind=enum, id=4325664, min=1, max=1, unit=0)
# 'conversion_factor_coeff': DCAMAttribute(name='CONVERSION FACTOR COEFF', kind=float, id=16769040, min=0.0, max=255.99, unit=0)
# 'conversion_factor_offset': DCAMAttribute(name='CONVERSION FACTOR OFFSET', kind=float, id=16769056, min=-65535.0, max=65535.0, unit=0)
# 'defect_correct_mode': DCAMAttribute(name='DEFECT CORRECT MODE', kind=enum, id=4653072, min=1, max=2, unit=0)
# 'exposure_time': DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 'frame_stamp_producer': DCAMAttribute(name='FRAME STAMP PRODUCER', kind=enum, id=4262432, min=5, max=5, unit=0)
# 'framebundle_frame_step_bytes': DCAMAttribute(name='FRAMEBUNDLE FRAME STEP BYTES', kind=int, id=4329536, min=18874368, max=18874368, unit=0)
# 'framebundle_mode': DCAMAttribute(name='FRAMEBUNDLE MODE', kind=enum, id=4329488, min=1, max=2, unit=0)
# 'framebundle_number': DCAMAttribute(name='FRAMEBUNDLE NUMBER', kind=int, id=4329504, min=2, max=2, unit=0)
# 'framebundle_rowbytes': DCAMAttribute(name='FRAMEBUNDLE ROWBYTES', kind=int, id=4329520, min=8192, max=8192, unit=0)
# 'hot_pixel_correct_level': DCAMAttribute(name='HOT PIXEL CORRECT LEVEL', kind=enum, id=4653104, min=1, max=3, unit=0)
# 'image_camera_stamp': DCAMAttribute(name='IMAGE CAMERA STAMP', kind=int, id=4326144, min=0, max=65535, unit=0)
# 'image_detector_pixel_height': DCAMAttribute(name='IMAGE DETECTOR PIXEL HEIGHT', kind=float, id=4327456, min=4.6000000000000005, max=4.6000000000000005, unit=7)
# 'image_detector_pixel_num_horz': DCAMAttribute(name='IMAGE DETECTOR PIXEL NUM HORZ', kind=int, id=4327472, min=4096, max=4096, unit=0)
# 'image_detector_pixel_num_vert': DCAMAttribute(name='IMAGE DETECTOR PIXEL NUM VERT', kind=int, id=4327488, min=2304, max=2304, unit=0)
# 'image_detector_pixel_width': DCAMAttribute(name='IMAGE DETECTOR PIXEL WIDTH', kind=float, id=4327440, min=4.6000000000000005, max=4.6000000000000005, unit=7)
# 'image_framebytes': DCAMAttribute(name='IMAGE FRAMEBYTES', kind=int, id=4325952, min=2, max=18874368, unit=0)
# 'image_height': DCAMAttribute(name='IMAGE HEIGHT', kind=int, id=4325920, min=4, max=2304, unit=0)
# 'image_pixel_type': DCAMAttribute(name='IMAGE PIXEL TYPE', kind=enum, id=4326000, min=1, max=3, unit=0)
# 'image_rowbytes': DCAMAttribute(name='IMAGE ROWBYTES', kind=int, id=4325936, min=2, max=8192, unit=0)
# 'image_top_offset_bytes': DCAMAttribute(name='IMAGE TOP OFFSET BYTES', kind=int, id=4325968, min=0, max=0, unit=0)
# 'image_width': DCAMAttribute(name='IMAGE WIDTH', kind=int, id=4325904, min=4, max=4096, unit=0)
# 'intensity_lut_mode': DCAMAttribute(name='INTENSITY LUT MODE', kind=enum, id=3671312, min=1, max=2, unit=0)
# 'intensity_lut_page': DCAMAttribute(name='INTENSITY LUT PAGE', kind=enum, id=3671328, min=1, max=1, unit=0)
# 'internal_frame_interval': DCAMAttribute(name='INTERNAL FRAME INTERVAL', kind=float, id=4208672, min=0.0564984, max=1800.0, unit=1)
# 'internal_frame_rate': DCAMAttribute(name='INTERNAL FRAME RATE', kind=float, id=4208656, min=0.0005555555555555556, max=17.69961627231922, unit=5)
# 'internal_line_interval': DCAMAttribute(name='INTERNAL LINE INTERVAL', kind=float, id=4208720, min=7.2e-06, max=7.2e-06, unit=1)
# 'internal_line_speed': DCAMAttribute(name='INTERNAL LINE SPEED', kind=float, id=4208704, min=0.638888888888889, max=0.638888888888889, unit=4)
# 'master_pulse_burst_times': DCAMAttribute(name='MASTER PULSE BURST TIMES', kind=int, id=1966160, min=1, max=65535, unit=0)
# 'master_pulse_interval': DCAMAttribute(name='MASTER PULSE INTERVAL', kind=float, id=1966144, min=4.9999999999999996e-06, max=10.0, unit=1)
# 'master_pulse_mode': DCAMAttribute(name='MASTER PULSE MODE', kind=enum, id=1966112, min=1, max=3, unit=0)
# 'master_pulse_trigger_source': DCAMAttribute(name='MASTER PULSE TRIGGER SOURCE', kind=enum, id=1966128, min=1, max=2, unit=0)
# 'number_of_output_trigger_connector': DCAMAttribute(name='NUMBER OF OUTPUT TRIGGER CONNECTOR', kind=int, id=1835024, min=3, max=3, unit=0)
# 'output_trigger_active[0]': DCAMAttribute(name='OUTPUT TRIGGER ACTIVE[0]', kind=enum, id=1835312, min=1, max=1, unit=0)
# 'output_trigger_delay[0]': DCAMAttribute(name='OUTPUT TRIGGER DELAY[0]', kind=float, id=1835328, min=0.0, max=10.0, unit=1)
# 'output_trigger_kind[0]': DCAMAttribute(name='OUTPUT TRIGGER KIND[0]', kind=enum, id=1835360, min=1, max=6, unit=0)
# 'output_trigger_period[0]': DCAMAttribute(name='OUTPUT TRIGGER PERIOD[0]', kind=float, id=1835344, min=1e-06, max=10.0, unit=1)
# 'output_trigger_polarity[0]': DCAMAttribute(name='OUTPUT TRIGGER POLARITY[0]', kind=enum, id=1835296, min=1, max=2, unit=0)
# 'output_trigger_pre_hsync_count': DCAMAttribute(name='OUTPUT TRIGGER PRE HSYNC COUNT', kind=int, id=1835408, min=0, max=4607, unit=0)
# 'output_trigger_source[0]': DCAMAttribute(name='OUTPUT TRIGGER SOURCE[0]', kind=enum, id=1835280, min=2, max=6, unit=0)
# 'readout_direction': DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0)
# 'readout_speed': DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0)
# 'record_fixed_bytes_per_file': DCAMAttribute(name='RECORD FIXED BYTES PER FILE', kind=int, id=4326416, min=256, max=256, unit=0)
# 'record_fixed_bytes_per_frame': DCAMAttribute(name='RECORD FIXED BYTES PER FRAME', kind=int, id=4326448, min=0, max=18874416, unit=0)
# 'record_fixed_bytes_per_session': DCAMAttribute(name='RECORD FIXED BYTES PER SESSION', kind=int, id=4326432, min=0, max=1016, unit=0)
# 'sensor_cooler_status': DCAMAttribute(name='SENSOR COOLER STATUS', kind=enum, id=2097984, min=1, max=3, unit=0)
# 'sensor_mode': DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0)
# 'sensor_temperature': DCAMAttribute(name='SENSOR TEMPERATURE', kind=float, id=2097936, min=-50.0, max=100.0, unit=2)
# 'subarray_hpos': DCAMAttribute(name='SUBARRAY HPOS', kind=int, id=4202768, min=0, max=4092, unit=0)
# 'subarray_hsize': DCAMAttribute(name='SUBARRAY HSIZE', kind=int, id=4202784, min=4, max=4096, unit=0)
# 'subarray_mode': DCAMAttribute(name='SUBARRAY MODE', kind=enum, id=4202832, min=1, max=2, unit=0)
# 'subarray_vpos': DCAMAttribute(name='SUBARRAY VPOS', kind=int, id=4202800, min=0, max=2300, unit=0)
# 'subarray_vsize': DCAMAttribute(name='SUBARRAY VSIZE', kind=int, id=4202816, min=4, max=2304, unit=0)
# 'system_alive': DCAMAttribute(name='SYSTEM ALIVE', kind=enum, id=16711696, min=1, max=2, unit=0)
# 'time_stamp_producer': DCAMAttribute(name='TIME STAMP PRODUCER', kind=enum, id=4262416, min=5, max=5, unit=0)
# 'timing_cyclic_trigger_period': DCAMAttribute(name='TIMING CYCLIC TRIGGER PERIOD', kind=float, id=4206624, min=0.0, max=0.0, unit=1)
# 'timing_exposure': DCAMAttribute(name='TIMING EXPOSURE', kind=enum, id=4206688, min=3, max=3, unit=0)
# 'timing_global_exposure_delay': DCAMAttribute(name='TIMING GLOBAL EXPOSURE DELAY', kind=float, id=4206736, min=0.0, max=0.008344800000000001, unit=1)
# 'timing_invalid_exposure_period': DCAMAttribute(name='TIMING INVALID EXPOSURE PERIOD', kind=float, id=4206704, min=0.0, max=2.88e-05, unit=1)
# 'timing_min_trigger_blanking': DCAMAttribute(name='TIMING MIN TRIGGER BLANKING', kind=float, id=4206640, min=0.0, max=0.0, unit=1)
# 'timing_min_trigger_interval': DCAMAttribute(name='TIMING MIN TRIGGER INTERVAL', kind=float, id=4206672, min=0.0, max=0.0, unit=1)
# 'timing_readout_time': DCAMAttribute(name='TIMING READOUT TIME', kind=float, id=4206608, min=0.0, max=0.0, unit=1)
# 'trigger_active': DCAMAttribute(name='TRIGGER ACTIVE', kind=enum, id=1048864, min=1, max=3, unit=0)
# 'trigger_connector': DCAMAttribute(name='TRIGGER CONNECTOR', kind=enum, id=1049136, min=2, max=2, unit=0)
# 'trigger_delay': DCAMAttribute(name='TRIGGER DELAY', kind=float, id=1049184, min=0.0, max=10.0, unit=1)
# 'trigger_global_exposure': DCAMAttribute(name='TRIGGER GLOBAL EXPOSURE', kind=enum, id=2032384, min=3, max=5, unit=0)
# 'trigger_mode': DCAMAttribute(name='TRIGGER MODE', kind=enum, id=1049104, min=1, max=6, unit=0)
# 'trigger_polarity': DCAMAttribute(name='TRIGGER POLARITY', kind=enum, id=1049120, min=1, max=2, unit=0)
# 'trigger_source': DCAMAttribute(name='TRIGGER SOURCE', kind=enum, id=1048848, min=1, max=4, unit=0)
# 'trigger_times': DCAMAttribute(name='TRIGGER TIMES', kind=int, id=1049152, min=1, max=10000, unit=0))

# %%
attrDict["binning"]
# Out:
# DCAMAttribute(name='BINNING', kind=enum, id=4198672, min=1, max=4, unit=0)

# %%
attrbin= attrDict["binning"]

# %%
attrbin
# Out:
# DCAMAttribute(name='BINNING', kind=enum, id=4198672, min=1, max=4, unit=0)

# %%
dir(attrbin)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_attributes_n',
#  '_update_enum_limits',
#  'as_text',
#  'default',
#  'get_value',
#  'handle',
#  'ilabels',
#  'ivalues',
#  'kind',
#  'labels',
#  'max',
#  'min',
#  'name',
#  'pid',
#  'readable',
#  'set_value',
#  'step',
#  'unit',
#  'update_limits',
#  'values',
#  'writable']

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds())
    print(type(cam.get_all_readout_speeds()))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# <class 'list'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_trigger_modes()) # 返回一个 list： ['slow', 'fast']
    print(type(cam.get_trigger_modes())) # 返回一个 list： ['slow', 'fast']
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\admin\Documents\camera\camera\hmmt_info.py:35
#      33 ## cam.get_all_attributes() # 等价于前述的 cam.attributes
#      34 print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
# ---> 35 print(cam.get_trigger_modes()) # 返回一个 list： ['slow', 'fast']
#      36 print(type(cam.get_trigger_modes()))
#
# AttributeError: 'DCAMCamera' object has no attribute 'get_trigger_modes'

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['slow', 'fast']
    print(type(cam.get_all_trigger_modes())) # 返回一个 list： ['slow', 'fast']
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# <class 'list'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    print(cam.get_attribute["exposure_time"])
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\admin\Documents\camera\camera\hmmt_info.py:36
#      34 print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
#      35 print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
# ---> 36 print(cam.get_attribute["exposure_time"])
#
# TypeError: 'method' object is not subscriptable

# %%
cam.get_attribute?
# Out:
# Signature: cam.get_attribute(name, error_on_missing=True)
# Docstring: Get the camera attribute with the given name
# File:      e:\anaconda\envs\camera\lib\site-packages\pylablib\devices\interface\camera.py
# Type:      method

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    print(cam.get_attribute("exposure_time"))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    print(cam.get_attribute_value("exposure_time")) # 等价于前述的 cam.cav["exposure_time"]
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# 0.0082944

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions())
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions())
    print(type(cam.get_data_dimensions()))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化
    print(cam.get_defect_correct_mode())
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size())
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(type(cam.get_device_info())) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# <class 'pylablib.devices.DCAM.DCAM.TDeviceInfo'>

# %%
cam.get_device_info()
# Out:
# ---------------------------------------------------------------------------
# DCAMLibError                              Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 cam.get_device_info()
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\DCAM\DCAM.py:237, in DCAMCamera.get_device_info(self)
#     231 def get_device_info(self):
#     232     """
#     233     Get camera model data.
#     234
#     235     Return tuple ``(vendor, model, serial_number, camera_version)``.
#     236     """
# --> 237     vendor=py3.as_str(lib.dcamdev_getstring(self.handle,dcamapi4_lib.DCAM_IDSTR.DCAM_IDSTR_VENDOR))
#     238     model=py3.as_str(lib.dcamdev_getstring(self.handle,dcamapi4_lib.DCAM_IDSTR.DCAM_IDSTR_MODEL))
#     239     serial_number=py3.as_str(lib.dcamdev_getstring(self.handle,dcamapi4_lib.DCAM_IDSTR.DCAM_IDSTR_CAMERAID))
#
# File <string>:1, in <lambda>(h, iString)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\utils\ctypes_wrap.py:276, in CFunctionWrapper.wrap_annotated.<locals>.wrapped_func(*vargs, **kwargs)
#     274         return a
#     275 call_args=[_to_call_arg(n,t,a) for (n,t,a) in zip(argnames,prep_argtypes,func_args)]
# --> 276 retval=func(*call_args)
#     277 res=self._convert_results(rvals or [None],dict(zip(argnames,func_args)),retval,kwargs,rconv)
#     278 if (not self.tuple_single_retval) and len(res)==0:
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\DCAM\dcamapi4_lib.py:44, in errcheck.<locals>.errchecker(result, func, arguments)
#      42     code=result
#      43 if code<0 and code not in passing: # positive codes are always success
# ---> 44     raise DCAMLibError(func.__name__,code)
#
# DCAMLibError: function 'dcamdev_getstring' raised error -2147481592 (DCAMERR_INVALIDPARAM)

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(type(cam.get_device_info())) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(list(cam.get_device_info())) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# <class 'pylablib.devices.DCAM.DCAM.TDeviceInfo'>
# ['Hamamatsu', 'C15550-20UP', 'S/N: 000352', '1.04']

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    print(cam.get_device_variable()) # brand, S/N, etc.
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\admin\Documents\camera\camera\hmmt_info.py:41
#      39 print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
#      40 print(cam.get_device_info()) # brand, S/N, etc.
# ---> 41 print(cam.get_device_variable())
#
# TypeError: IDevice.get_device_variable() missing 1 required positional argument: 'key'

# %%
cam.get_device_variable?
# Out:
# Signature: cam.get_device_variable(key)
# Docstring: Get the value of a settings, status, or full info parameter
# File:      e:\anaconda\envs\camera\lib\site-packages\pylablib\core\devio\interface.py
# Type:      method

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    # print(cam.get_device_variable()) # brand, S/N, etc.
    print(cam._device_vars) # brand, S/N, etc.
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# {'settings': {'image_indexing': (<bound method ICamera.get_image_indexing of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF67A5C0>, (), 0), 'frame_format': (<bound method ICamera.get_frame_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF678AE0>, (), 0), 'frame_info_format': (<bound method ICamera.get_frame_info_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF67BE20>, (), 0), 'frame_info_period': (<bound method ICamera.get_frame_info_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF679B20>, (), 0), 'exposure': (<bound method DCAMCamera.get_exposure of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF678FE0>, (), 0), 'roi': (<bound method DCAMCamera.get_roi of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6793A0>, (), 0), 'trigger_mode': (<bound method DCAMCamera.get_trigger_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF652CA0>, (<class 'ValueError'>,), 0), 'ext_trigger': (<bound method DCAMCamera.get_ext_trigger_parameters of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DEC90D60>, (), 0), 'readout_speed': (<bound method DCAMCamera.get_readout_speed of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DEC92AC0>, (<class 'ValueError'>,), 0), 'defect_correct_mode': (<bound method DCAMCamera.get_defect_correct_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DEC91E40>, (<class 'ValueError'>,), 0)}, 'status': {'buffer_size': (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4DEC4B880>, None, (), 0), 'acquired_frames': (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4DF674B80>, None, (), 0), 'acquisition_in_progress': (<bound method DCAMCamera.acquisition_in_progress of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, None, (), 0), 'frames_status': (<bound method ICamera.get_frames_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, None, (), 0), 'data_dimensions': (<bound method ICamera.get_data_dimensions of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, None, (), 0), 'camera_attributes': (<bound method DCAMCamera.get_all_attribute_values of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, None, (), -5), 'frame_timings': (<bound method DCAMCamera.get_frame_timings of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, None, (), 0), 'roi_limits': (<bound method DCAMCamera.get_roi_limits of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, None, (), 0), 'readout_time': (<bound method DCAMCamera.get_frame_readout_time of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, None, (), 0), 'acq_status': (<bound method DCAMCamera.get_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, None, (), 0), 'transfer_info': (<bound method DCAMCamera.get_transfer_info of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F28D0>>, None, (), 0), 'frame_period': (<bound method IExposureCamera.get_frame_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x00000 ...

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    # print(cam.get_device_variable()) # brand, S/N, etc.
    # print(cam._device_vars) # brand, S/N, etc.
    for e in cam._device_vars.items(): print(e)
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# ('settings', {'image_indexing': (<bound method ICamera.get_image_indexing of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6BF920>, (), 0), 'frame_format': (<bound method ICamera.get_frame_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6BD6C0>, (), 0), 'frame_info_format': (<bound method ICamera.get_frame_info_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6BE3E0>, (), 0), 'frame_info_period': (<bound method ICamera.get_frame_info_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6BE5C0>, (), 0), 'exposure': (<bound method DCAMCamera.get_exposure of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6BE2A0>, (), 0), 'roi': (<bound method DCAMCamera.get_roi of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6BEA20>, (), 0), 'trigger_mode': (<bound method DCAMCamera.get_trigger_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6AA480>, (<class 'ValueError'>,), 0), 'ext_trigger': (<bound method DCAMCamera.get_ext_trigger_parameters of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DEC6C9A0>, (), 0), 'readout_speed': (<bound method DCAMCamera.get_readout_speed of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DEC6E020>, (<class 'ValueError'>,), 0), 'defect_correct_mode': (<bound method DCAMCamera.get_defect_correct_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DEC6FCE0>, (<class 'ValueError'>,), 0)})
# ('status', {'buffer_size': (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4DF71C040>, None, (), 0), 'acquired_frames': (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4DF71E7A0>, None, (), 0), 'acquisition_in_progress': (<bound method DCAMCamera.acquisition_in_progress of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'frames_status': (<bound method ICamera.get_frames_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'data_dimensions': (<bound method ICamera.get_data_dimensions of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'camera_attributes': (<bound method DCAMCamera.get_all_attribute_values of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), -5), 'frame_timings': (<bound method DCAMCamera.get_frame_timings of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'roi_limits': (<bound method DCAMCamera.get_roi_limits of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'readout_time': (<bound method DCAMCamera.get_frame_readout_time of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'acq_status': (<bound method DCAMCamera.get_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'transfer_info': (<bound method DCAMCamera.get_transfer_info of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'frame_period': (<bound method IExposureCamera.get_frame_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0)})
# ('info', {'cls': (<function IDevice.__init__.<locals>.<lambda> at 0x000002E4DF71FA60>, None, (), 0), 'conn': (<bound method DCAMCamera._get_connection_parameters of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (<class 'NotImplementedError'>,), 0), 'detector_size': (<bound method DCAMCamera.get_detector_size of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'frame_info_fields': (<bound method ICamera.get_frame_info_fields of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'device_info': (<bound method DCAMCamera.get_device_info of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'all_trigger_modes': (<bound method DCAMCamera.get_all_trigger_modes of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0), 'all_readout_speeds': (<bound method DCAMCamera.get_all_readout_speeds of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07F06E0>>, None, (), 0)})

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    # print(cam.get_device_variable()) # brand, S/N, etc.
    # print(cam._device_vars) # brand, S/N, etc.
    for e in cam._device_vars["settings"].items(): print(e)
    for e in cam._device_vars["status"].items(): print(e)
    for e in cam._device_vars["info"].items(): print(e)
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# ('image_indexing', (<bound method ICamera.get_image_indexing of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF71E5C0>, (), 0))
# ('frame_format', (<bound method ICamera.get_frame_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF71EAC0>, (), 0))
# ('frame_info_format', (<bound method ICamera.get_frame_info_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF71DF80>, (), 0))
# ('frame_info_period', (<bound method ICamera.get_frame_info_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF71FCE0>, (), 0))
# ('exposure', (<bound method DCAMCamera.get_exposure of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF71CE00>, (), 0))
# ('roi', (<bound method DCAMCamera.get_roi of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF71F740>, (), 0))
# ('trigger_mode', (<bound method DCAMCamera.get_trigger_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D0D8A0>, (<class 'ValueError'>,), 0))
# ('ext_trigger', (<bound method DCAMCamera.get_ext_trigger_parameters of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D0DA80>, (), 0))
# ('readout_speed', (<bound method DCAMCamera.get_readout_speed of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D0DB20>, (<class 'ValueError'>,), 0))
# ('defect_correct_mode', (<bound method DCAMCamera.get_defect_correct_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D0DBC0>, (<class 'ValueError'>,), 0))
# ('buffer_size', (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4DF71E2A0>, None, (), 0))
# ('acquired_frames', (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4DF71CCC0>, None, (), 0))
# ('acquisition_in_progress', (<bound method DCAMCamera.acquisition_in_progress of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('frames_status', (<bound method ICamera.get_frames_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('data_dimensions', (<bound method ICamera.get_data_dimensions of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('camera_attributes', (<bound method DCAMCamera.get_all_attribute_values of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), -5))
# ('frame_timings', (<bound method DCAMCamera.get_frame_timings of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('roi_limits', (<bound method DCAMCamera.get_roi_limits of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('readout_time', (<bound method DCAMCamera.get_frame_readout_time of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('acq_status', (<bound method DCAMCamera.get_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('transfer_info', (<bound method DCAMCamera.get_transfer_info of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('frame_period', (<bound method IExposureCamera.get_frame_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('cls', (<function IDevice.__init__.<locals>.<lambda> at 0x000002E4DF71DEE0>, None, (), 0))
# ('conn', (<bound method DCAMCamera._get_connection_parameters of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (<class 'NotImplementedError'>,), 0))
# ('detector_size', (<bound method DCAMCamera.get_detector_size of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('frame_info_fields', (<bound method ICamera.get_frame_info_fields of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('device_info', (<bound method DCAMCamera.get_device_info of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('all_trigger_modes', (<bound method DCAMCamera.get_all_trigger_modes of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))
# ('all_readout_speeds', (<bound method DCAMCamera.get_all_readout_speeds of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07DF260>>, None, (), 0))

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    print(cam.get_device_variable("trigger_mode")) # brand, S/N, etc.
    # print(cam._device_vars) # brand, S/N, etc.
    for e in cam._device_vars["settings"].items(): print(e)
    for e in cam._device_vars["status"].items(): print(e)
    for e in cam._device_vars["info"].items(): print(e)
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# int
# ('image_indexing', (<bound method ICamera.get_image_indexing of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF668E00>, (), 0))
# ('frame_format', (<bound method ICamera.get_frame_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6687C0>, (), 0))
# ('frame_info_format', (<bound method ICamera.get_frame_info_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF66B4C0>, (), 0))
# ('frame_info_period', (<bound method ICamera.get_frame_info_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6698A0>, (), 0))
# ('exposure', (<bound method DCAMCamera.get_exposure of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF668360>, (), 0))
# ('roi', (<bound method DCAMCamera.get_roi of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF669080>, (), 0))
# ('trigger_mode', (<bound method DCAMCamera.get_trigger_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D22840>, (<class 'ValueError'>,), 0))
# ('ext_trigger', (<bound method DCAMCamera.get_ext_trigger_parameters of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D22A20>, (), 0))
# ('readout_speed', (<bound method DCAMCamera.get_readout_speed of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D22AC0>, (<class 'ValueError'>,), 0))
# ('defect_correct_mode', (<bound method DCAMCamera.get_defect_correct_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D22B60>, (<class 'ValueError'>,), 0))
# ('buffer_size', (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4DF669620>, None, (), 0))
# ('acquired_frames', (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4DF668FE0>, None, (), 0))
# ('acquisition_in_progress', (<bound method DCAMCamera.acquisition_in_progress of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('frames_status', (<bound method ICamera.get_frames_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('data_dimensions', (<bound method ICamera.get_data_dimensions of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('camera_attributes', (<bound method DCAMCamera.get_all_attribute_values of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), -5))
# ('frame_timings', (<bound method DCAMCamera.get_frame_timings of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('roi_limits', (<bound method DCAMCamera.get_roi_limits of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('readout_time', (<bound method DCAMCamera.get_frame_readout_time of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('acq_status', (<bound method DCAMCamera.get_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('transfer_info', (<bound method DCAMCamera.get_transfer_info of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('frame_period', (<bound method IExposureCamera.get_frame_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('cls', (<function IDevice.__init__.<locals>.<lambda> at 0x000002E4DF69CF40>, None, (), 0))
# ('conn', (<bound method DCAMCamera._get_connection_parameters of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (<class 'NotImplementedError'>,), 0))
# ('detector_size', (<bound method DCAMCamera.get_detector_size of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('frame_info_fields', (<bound method ICamera.get_frame_info_fields of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('device_info', (<bound method DCAMCamera.get_device_info of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('all_trigger_modes', (<bound method DCAMCamera.get_all_trigger_modes of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))
# ('all_readout_speeds', (<bound method DCAMCamera.get_all_readout_speeds of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07EBAA0>>, None, (), 0))

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    print(cam.get_device_variable("trigger_mode")) # brand, S/N, etc.
    # print(cam._device_vars) # brand, S/N, etc.\
    print("===settings==")
    for e in cam._device_vars["settings"].items(): print(cam.get_device_variable(e[0]))
    print("===status==")
    for e in cam._device_vars["status"].items(): print(cam.get_device_variable(e[0]))
    print("===info==")
    for e in cam._device_vars["info"].items(): print(cam.get_device_variable(e[0]))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# int
# ===settings==
# rct
# list
# namedtuple
# 1
# 0.0082944
# (0, 4096, 0, 2304, 1, 1)
# int
# (False, 0.0)
# fast
# True
# ===status==
# 0
# 0
# False
# TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# (2304, 4096)
# Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# 0.0564984
# unstable
# (-1, 0)
# 0.0564984
# ===info==
# DCAMCamera
# 0
# (4096, 2304)
# ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# ['int', 'ext', 'software', 'master_pulse']
# ['slow', 'fast']

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    print(cam.get_device_variable("trigger_mode")) # brand, S/N, etc.
    # print(cam._device_vars) # brand, S/N, etc.\
    print("===settings==")
    for e in cam._device_vars["settings"].items(): print(e[0], cam.get_device_variable(e[0]))
    print("===status==")
    for e in cam._device_vars["status"].items(): print(e[0], cam.get_device_variable(e[0]))
    print("===info==")
    for e in cam._device_vars["info"].items(): print(e[0], cam.get_device_variable(e[0]))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# int
# ===settings==
# image_indexing rct
# frame_format list
# frame_info_format namedtuple
# frame_info_period 1
# exposure 0.0082944
# roi (0, 4096, 0, 2304, 1, 1)
# trigger_mode int
# ext_trigger (False, 0.0)
# readout_speed fast
# defect_correct_mode True
# ===status==
# buffer_size 0
# acquired_frames 0
# acquisition_in_progress False
# frames_status TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions (2304, 4096)
# camera_attributes Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time 0.0564984
# acq_status unstable
# transfer_info (-1, 0)
# frame_period 0.0564984
# ===info==
# cls DCAMCamera
# conn 0
# detector_size (4096, 2304)
# frame_info_fields ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds ['slow', 'fast']

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    print(cam.get_device_variable("trigger_mode")) # brand, S/N, etc.
    # print(cam._device_vars) # brand, S/N, etc.\
    print("===settings==")
    for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===status==")
    for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===info==")
    for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# int
# ===settings==
# image_indexing || rct
# frame_format || list
# frame_info_format || namedtuple
# frame_info_period || 1
# exposure || 0.0082944
# roi || (0, 4096, 0, 2304, 1, 1)
# trigger_mode || int
# ext_trigger || (False, 0.0)
# readout_speed || fast
# defect_correct_mode || True
# ===status==
# buffer_size || 0
# acquired_frames || 0
# acquisition_in_progress || False
# frames_status || TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions || (2304, 4096)
# camera_attributes || Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings || TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits || (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time || 0.0564984
# acq_status || unstable
# transfer_info || (-1, 0)
# frame_period || 0.0564984
# ===info==
# cls || DCAMCamera
# conn || 0
# detector_size || (4096, 2304)
# frame_info_fields || ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info || TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes || ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds || ['slow', 'fast']

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    print(cam._device_vars) 
    print("===settings==")
    for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===status==")
    for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===info==")
    for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# {'settings': {'image_indexing': (<bound method ICamera.get_image_indexing of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D32B60>, (), 0), 'frame_format': (<bound method ICamera.get_frame_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D30FE0>, (), 0), 'frame_info_format': (<bound method ICamera.get_frame_info_format of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D31BC0>, (), 0), 'frame_info_period': (<bound method ICamera.get_frame_info_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D32700>, (), 0), 'exposure': (<bound method DCAMCamera.get_exposure of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D32A20>, (), 0), 'roi': (<bound method DCAMCamera.get_roi of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4E0D32F20>, (), 0), 'trigger_mode': (<bound method DCAMCamera.get_trigger_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6BD080>, (<class 'ValueError'>,), 0), 'ext_trigger': (<bound method DCAMCamera.get_ext_trigger_parameters of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6BE480>, (), 0), 'readout_speed': (<bound method DCAMCamera.get_readout_speed of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF6BCD60>, (<class 'ValueError'>,), 0), 'defect_correct_mode': (<bound method DCAMCamera.get_defect_correct_mode of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, <function IDevice._add_device_variable.<locals>.<lambda> at 0x000002E4DF71C040>, (<class 'ValueError'>,), 0)}, 'status': {'buffer_size': (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4E0D31B20>, None, (), 0), 'acquired_frames': (<function ICamera.__init__.<locals>.<lambda> at 0x000002E4E0D31D00>, None, (), 0), 'acquisition_in_progress': (<bound method DCAMCamera.acquisition_in_progress of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, None, (), 0), 'frames_status': (<bound method ICamera.get_frames_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, None, (), 0), 'data_dimensions': (<bound method ICamera.get_data_dimensions of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, None, (), 0), 'camera_attributes': (<bound method DCAMCamera.get_all_attribute_values of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, None, (), -5), 'frame_timings': (<bound method DCAMCamera.get_frame_timings of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, None, (), 0), 'roi_limits': (<bound method DCAMCamera.get_roi_limits of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, None, (), 0), 'readout_time': (<bound method DCAMCamera.get_frame_readout_time of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, None, (), 0), 'acq_status': (<bound method DCAMCamera.get_status of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, None, (), 0), 'transfer_info': (<bound method DCAMCamera.get_transfer_info of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x000002E4E07FAC30>>, None, (), 0), 'frame_period': (<bound method IExposureCamera.get_frame_period of <pylablib.devices.DCAM.DCAM.DCAMCamera object at 0x00000 ...
# ===settings==
# image_indexing || rct
# frame_format || list
# frame_info_format || namedtuple
# frame_info_period || 1
# exposure || 0.0082944
# roi || (0, 4096, 0, 2304, 1, 1)
# trigger_mode || int
# ext_trigger || (False, 0.0)
# readout_speed || fast
# defect_correct_mode || True
# ===status==
# buffer_size || 0
# acquired_frames || 0
# acquisition_in_progress || False
# frames_status || TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions || (2304, 4096)
# camera_attributes || Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings || TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits || (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time || 0.0564984
# acq_status || unstable
# transfer_info || (-1, 0)
# frame_period || 0.0564984
# ===info==
# cls || DCAMCamera
# conn || 0
# detector_size || (4096, 2304)
# frame_info_fields || ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info || TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes || ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds || ['slow', 'fast']

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    print(cam._device_vars.keys()) 
    print("===settings==")
    for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===status==")
    for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===info==")
    for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# dict_keys(['settings', 'status', 'info'])
# ===settings==
# image_indexing || rct
# frame_format || list
# frame_info_format || namedtuple
# frame_info_period || 1
# exposure || 0.0082944
# roi || (0, 4096, 0, 2304, 1, 1)
# trigger_mode || int
# ext_trigger || (False, 0.0)
# readout_speed || fast
# defect_correct_mode || True
# ===status==
# buffer_size || 0
# acquired_frames || 0
# acquisition_in_progress || False
# frames_status || TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions || (2304, 4096)
# camera_attributes || Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings || TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits || (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time || 0.0564984
# acq_status || unstable
# transfer_info || (-1, 0)
# frame_period || 0.0564984
# ===info==
# cls || DCAMCamera
# conn || 0
# detector_size || (4096, 2304)
# frame_info_fields || ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info || TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes || ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds || ['slow', 'fast']

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    ## all possible outputs of cam.get_devices_variable():
    print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
    print("===settings==")
    for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===status==")
    for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===info==")
    for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print(cam.get_exposure())
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# dict_keys(['settings', 'status', 'info'])
# ===settings==
# image_indexing || rct
# frame_format || list
# frame_info_format || namedtuple
# frame_info_period || 1
# exposure || 0.0082944
# roi || (0, 4096, 0, 2304, 1, 1)
# trigger_mode || int
# ext_trigger || (False, 0.0)
# readout_speed || fast
# defect_correct_mode || True
# ===status==
# buffer_size || 0
# acquired_frames || 0
# acquisition_in_progress || False
# frames_status || TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions || (2304, 4096)
# camera_attributes || Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings || TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits || (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time || 0.0564984
# acq_status || unstable
# transfer_info || (-1, 0)
# frame_period || 0.0564984
# ===info==
# cls || DCAMCamera
# conn || 0
# detector_size || (4096, 2304)
# frame_info_fields || ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info || TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes || ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds || ['slow', 'fast']
# 0.0082944

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    ## all possible outputs of cam.get_devices_variable():
    print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
    print("===settings==")
    for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===status==")
    for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===info==")
    for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_devices_variable("exposure")
    print(cam.get_devices_variable("exposure"))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# dict_keys(['settings', 'status', 'info'])
# ===settings==
# image_indexing || rct
# frame_format || list
# frame_info_format || namedtuple
# frame_info_period || 1
# exposure || 0.0082944
# roi || (0, 4096, 0, 2304, 1, 1)
# trigger_mode || int
# ext_trigger || (False, 0.0)
# readout_speed || fast
# defect_correct_mode || True
# ===status==
# buffer_size || 0
# acquired_frames || 0
# acquisition_in_progress || False
# frames_status || TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions || (2304, 4096)
# camera_attributes || Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings || TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits || (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time || 0.0564984
# acq_status || unstable
# transfer_info || (-1, 0)
# frame_period || 0.0564984
# ===info==
# cls || DCAMCamera
# conn || 0
# detector_size || (4096, 2304)
# frame_info_fields || ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info || TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes || ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds || ['slow', 'fast']
# 0.0082944
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\admin\Documents\camera\camera\hmmt_info.py:50
#      48 for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
#      49 print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_devices_variable("exposure")
# ---> 50 print(cam.get_devices_variable("exposure"))
#
# AttributeError: 'DCAMCamera' object has no attribute 'get_devices_variable'

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    ## all possible outputs of cam.get_devices_variable():
    print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
    print("===settings==")
    for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===status==")
    for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===info==")
    for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_devices_variable("exposure")
    print(cam.get_device_variable("exposure"))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# dict_keys(['settings', 'status', 'info'])
# ===settings==
# image_indexing || rct
# frame_format || list
# frame_info_format || namedtuple
# frame_info_period || 1
# exposure || 0.0082944
# roi || (0, 4096, 0, 2304, 1, 1)
# trigger_mode || int
# ext_trigger || (False, 0.0)
# readout_speed || fast
# defect_correct_mode || True
# ===status==
# buffer_size || 0
# acquired_frames || 0
# acquisition_in_progress || False
# frames_status || TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions || (2304, 4096)
# camera_attributes || Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings || TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits || (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time || 0.0564984
# acq_status || unstable
# transfer_info || (-1, 0)
# frame_period || 0.0564984
# ===info==
# cls || DCAMCamera
# conn || 0
# detector_size || (4096, 2304)
# frame_info_fields || ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info || TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes || ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds || ['slow', 'fast']
# 0.0082944
# 0.0082944

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)

    print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
    ## cam.apply_settings() # takes a key-val setting dict
    assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
    attrDict = cam.attributes # 方便 close cam 后查看
    for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
    print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
    attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
    print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
        attr.get_value(), # 也可以用后面的 cav 方法获得
        attr.min, 
        attr.max,
        attr.readable,
        attr.writable,
        attr.step, # 值可变的最小单位
        attr.unit, # not sure what this is 
        attr.values, # not sure what it does, 返回列表
        ) 
    print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
    ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
    ## cam.close() # the good'ol close. 用 with 语句时完全用不着
    ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
    ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
    print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
    for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
    ## cam.get_all_attributes() # 等价于前述的 cam.attributes
    print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
    print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
    ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
    ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
    print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
    print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
    print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
    print(cam.get_device_info()) # brand, S/N, etc.
    ## all possible outputs of cam.get_devices_variable():
    print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
    print("===settings==")
    for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===status==")
    for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    print("===info==")
    for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
    ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    print(cam.get_ext_trigger_parameters())
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# dict_keys(['settings', 'status', 'info'])
# ===settings==
# image_indexing || rct
# frame_format || list
# frame_info_format || namedtuple
# frame_info_period || 1
# exposure || 0.0082944
# roi || (0, 4096, 0, 2304, 1, 1)
# trigger_mode || int
# ext_trigger || (False, 0.0)
# readout_speed || fast
# defect_correct_mode || True
# ===status==
# buffer_size || 0
# acquired_frames || 0
# acquisition_in_progress || False
# frames_status || TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions || (2304, 4096)
# camera_attributes || Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings || TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits || (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time || 0.0564984
# acq_status || unstable
# transfer_info || (-1, 0)
# frame_period || 0.0564984
# ===info==
# cls || DCAMCamera
# conn || 0
# detector_size || (4096, 2304)
# frame_info_fields || ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info || TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes || ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds || ['slow', 'fast']
# (False, 0.0)
# <class 'tuple'>

# %%
cam.get_ext_trigger_parameters?
# Out:
# Signature: cam.get_ext_trigger_parameters()
# Docstring: Return external trigger parameters (inversion and delay)
# File:      e:\anaconda\envs\camera\lib\site-packages\pylablib\devices\dcam\dcam.py
# Type:      method

# %%
attrDict["trigger_mode"]
# Out:
# DCAMAttribute(name='TRIGGER MODE', kind=enum, id=1049104, min=1, max=6, unit=0)

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.ca["trigger_mode"]=2
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\admin\Documents\camera\camera\hmmt_info.py:50
#      48     for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
#      49     ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
# ---> 50 cam.ca["trigger_mode"]=2
#      51 print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple,
#      52 print(type(cam.get_ext_trigger_parameters()))
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\utils\dictionary.py:1464, in ItemAccessor.__setitem__(self, name, value)
#    1462 if self.setter is not None:
#    1463     return self.setter(name, value)
# -> 1464 raise NotImplementedError("setter is not specified")
#
# NotImplementedError: setter is not specified

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode(2)
    print(cam.cav["trigger_mode"])
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode(3)
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode"))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# 1
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode(3)
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode(4)
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode(5)
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\admin\Documents\camera\camera\hmmt_info.py:50
#      48     for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
#      49     ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
# ---> 50 cam.set_trigger_mode(5)
#      51 print(cam.cav["trigger_mode"])
#      52 print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\interface\camera.py:701, in acqstopped.<locals>.wrapper.<locals>.wrapped(self, *args, **kwargs)
#     699     raise self.Error("method {} can not be called when the acquisition is in progress".format(func.__name__))
#     700 with self.pausing_acquisition(clear=False):
# --> 701     return func(self,*args,**kwargs)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\devio\interface.py:665, in use_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     663 @functools.wraps(func)
#     664 def wrapped(*args, **kwargs):
# --> 665     all_args=parse_args(args,kwargs)
#     666     res=func(**all_args)
#     667     return parse_reply(res,args,kwargs)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\devio\interface.py:643, in use_parameters.<locals>.wrapper.<locals>.parse_args(args, kwargs)
#     641     if params[n] is not None:
#     642         par=obj_params.get(params[n],params[n])
# --> 643         all_args[n]=par(all_args[n],device=device)
#     644 elif obj_params.get(n) is not None:
#     645     all_args[n]=obj_params[n](all_args[n],device=device)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\devio\interface.py:358, in ICheckingParameterClass.__call__(self, alias, device)
#     356 with self.using_device(device):
#     357     if not self.check_alias(alias):
# --> 358         raise ValueError(self._alias_error_str(alias))
#     359     return self.to_value(alias)
#
# ValueError: invalid value 5 for the trigger_mode; allowed values are 'int', 'ext', 'software', 'master_pulse'

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode("ext")
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode("software")
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode("softwarse")
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\admin\Documents\camera\camera\hmmt_info.py:50
#      48     for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
#      49     ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
# ---> 50 cam.set_trigger_mode("softwarse")
#      51 print(cam.cav["trigger_mode"])
#      52 print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\interface\camera.py:701, in acqstopped.<locals>.wrapper.<locals>.wrapped(self, *args, **kwargs)
#     699     raise self.Error("method {} can not be called when the acquisition is in progress".format(func.__name__))
#     700 with self.pausing_acquisition(clear=False):
# --> 701     return func(self,*args,**kwargs)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\devio\interface.py:665, in use_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     663 @functools.wraps(func)
#     664 def wrapped(*args, **kwargs):
# --> 665     all_args=parse_args(args,kwargs)
#     666     res=func(**all_args)
#     667     return parse_reply(res,args,kwargs)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\devio\interface.py:643, in use_parameters.<locals>.wrapper.<locals>.parse_args(args, kwargs)
#     641     if params[n] is not None:
#     642         par=obj_params.get(params[n],params[n])
# --> 643         all_args[n]=par(all_args[n],device=device)
#     644 elif obj_params.get(n) is not None:
#     645     all_args[n]=obj_params[n](all_args[n],device=device)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\devio\interface.py:358, in ICheckingParameterClass.__call__(self, alias, device)
#     356 with self.using_device(device):
#     357     if not self.check_alias(alias):
# --> 358         raise ValueError(self._alias_error_str(alias))
#     359     return self.to_value(alias)
#
# ValueError: invalid value 'softwarse' for the trigger_mode; allowed values are 'int', 'ext', 'software', 'master_pulse'

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    attr = cam.ca["trigger_mode"]
    cam.set_trigger_mode("software")
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
dir(attr)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_attributes_n',
#  '_update_enum_limits',
#  'as_text',
#  'default',
#  'get_value',
#  'handle',
#  'ilabels',
#  'ivalues',
#  'kind',
#  'labels',
#  'max',
#  'min',
#  'name',
#  'pid',
#  'readable',
#  'set_value',
#  'step',
#  'unit',
#  'update_limits',
#  'values',
#  'writable']

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    attr = cam.ca["trigger_mode"]
    cam.set_trigger_mode("software")
    attr.update_limits()
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    attr = cam.ca["trigger_mode"]
    cam.set_trigger_mode("ext")
    attr.update_limits()
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    attr = cam.ca["trigger_mode"]
    cam.set_trigger_mode("ext")
    print(attr.get_value())
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    attr = cam.ca["trigger_mode"]
    cam.set_trigger_mode("ext")
    frame = cam.snap()
    print(attr.get_value())
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# ---------------------------------------------------------------------------
# DCAMTimeoutError                          Traceback (most recent call last)
# File c:\Users\admin\Documents\camera\camera\hmmt_info.py:52
#      50 attr = cam.ca["trigger_mode"]
#      51 cam.set_trigger_mode("ext")
# ---> 52 frame = cam.snap()
#      53 print(attr.get_value())
#      54 print(cam.cav["trigger_mode"])
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\interface\camera.py:682, in ICamera.snap(self, timeout, return_info)
#     680 def snap(self, timeout=5., return_info=False):
#     681     """Snap a single frame"""
# --> 682     res=self.grab(frame_timeout=timeout,return_info=return_info)
#     683     if return_info:
#     684         return _first_frame(*res,chunks=self.get_frame_format()=="chunks")
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\interface\camera.py:668, in ICamera.grab(self, nframes, frame_timeout, missing_frame, return_info, buff_size)
#     666 try:
#     667     while nacq<nframes:
# --> 668         self.wait_for_frame(timeout=frame_timeout)
#     669         if return_info:
#     670             new_frames,new_info,rng=self.read_multiple_images(missing_frame=missing_frame,return_info=True,return_rng=True)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\devio\interface.py:666, in use_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     663 @functools.wraps(func)
#     664 def wrapped(*args, **kwargs):
#     665     all_args=parse_args(args,kwargs)
# --> 666     res=func(**all_args)
#     667     return parse_reply(res,args,kwargs)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\interface\camera.py:262, in ICamera.wait_for_frame(self, since, nframes, timeout, error_on_stopped)
#     260         to=fto if to is None else min(to,fto)
#     261     if to is not None and to<=0:
# --> 262         raise self.TimeoutError
#     263     self._wait_for_next_frame(timeout=to,idx=acquired_frames)
#     264 self._frame_counter.wait_done()
#
# DCAMTimeoutError:

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    attr = cam.ca["trigger_mode"]
    # cam.set_trigger_mode("ext")
    frame = cam.snap()
    print(attr.get_value())
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode("ext")
    attr = cam.ca["trigger_mode"]
    print(attr.get_value())
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if True:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode("ext")
    attr = cam.ca["trigger_mode"]
    print(attr.get_value())
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# dict_keys(['settings', 'status', 'info'])
# ===settings==
# image_indexing || rct
# frame_format || list
# frame_info_format || namedtuple
# frame_info_period || 1
# exposure || 0.0082944
# roi || (0, 4096, 0, 2304, 1, 1)
# trigger_mode || int
# ext_trigger || (False, 0.0)
# readout_speed || fast
# defect_correct_mode || True
# ===status==
# buffer_size || 0
# acquired_frames || 0
# acquisition_in_progress || False
# frames_status || TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions || (2304, 4096)
# camera_attributes || Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings || TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits || (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time || 0.0564984
# acq_status || unstable
# transfer_info || (-1, 0)
# frame_period || 0.0564984
# ===info==
# cls || DCAMCamera
# conn || 0
# detector_size || (4096, 2304)
# frame_info_fields || ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info || TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes || ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds || ['slow', 'fast']
# 1
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if True:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode("ext")
    attr = cam.ca["trigger_mode"]
    print(cam.get_device_variable("camera_attributes")["trigger_mode"]) # 也可以用 get_device_variable 来获得 trigger_mode 的值
    print(attr.get_value())
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# False
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1)
# 0.0082944 7.2e-06 1800.0 True True 1e-08 1 []
# 0.0082944
# None
# ('sensor_mode', 'AREA')
# ('readout_speed', 2)
# ('readout_direction', 'FORWARD')
# ['slow', 'fast']
# ['int', 'ext', 'software', 'master_pulse']
# (2304, 4096)
# True
# (4096, 2304)
# TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# dict_keys(['settings', 'status', 'info'])
# ===settings==
# image_indexing || rct
# frame_format || list
# frame_info_format || namedtuple
# frame_info_period || 1
# exposure || 0.0082944
# roi || (0, 4096, 0, 2304, 1, 1)
# trigger_mode || int
# ext_trigger || (False, 0.0)
# readout_speed || fast
# defect_correct_mode || True
# ===status==
# buffer_size || 0
# acquired_frames || 0
# acquisition_in_progress || False
# frames_status || TFramesStatus(acquired=0, unread=0, skipped=0, buffer_size=0)
# data_dimensions || (2304, 4096)
# camera_attributes || Dictionary('binning': 1
# 'bit_per_channel': 16
# 'buffer_framebytes': 18874368
# 'buffer_pixel_type': 2
# 'buffer_rowbytes': 8192
# 'buffer_top_offset_bytes': 0
# 'capture_mode': 1
# 'colortype': 1
# 'conversion_factor_coeff': 0.1
# 'conversion_factor_offset': 200.0
# 'defect_correct_mode': 2
# 'exposure_time': 0.0082944
# 'frame_stamp_producer': 5
# 'framebundle_frame_step_bytes': 18874368
# 'framebundle_mode': 1
# 'framebundle_number': 2
# 'framebundle_rowbytes': 8192
# 'hot_pixel_correct_level': 1
# 'image_camera_stamp': 0
# 'image_detector_pixel_height': 4.6000000000000005
# 'image_detector_pixel_num_horz': 4096
# 'image_detector_pixel_num_vert': 2304
# 'image_detector_pixel_width': 4.6000000000000005
# 'image_framebytes': 18874368
# 'image_height': 2304
# 'image_pixel_type': 2
# 'image_rowbytes': 8192
# 'image_top_offset_bytes': 0
# 'image_width': 4096
# 'intensity_lut_mode': 1
# 'intensity_lut_page': 1
# 'internal_frame_interval': 0.0564984
# 'internal_frame_rate': 17.69961627231922
# 'internal_line_interval': 7.2e-06
# 'internal_line_speed': 0.638888888888889
# 'master_pulse_burst_times': 1
# 'master_pulse_interval': 0.1
# 'master_pulse_mode': 1
# 'master_pulse_trigger_source': 1
# 'number_of_output_trigger_connector': 3
# 'output_trigger_active[0]': 1
# 'output_trigger_delay[0]': 0.0
# 'output_trigger_kind[0]': 1
# 'output_trigger_period[0]': 0.0009999999999999998
# 'output_trigger_polarity[0]': 1
# 'output_trigger_pre_hsync_count': 0
# 'output_trigger_source[0]': 2
# 'readout_direction': 1
# 'readout_speed': 2
# 'record_fixed_bytes_per_file': 256
# 'record_fixed_bytes_per_frame': 18874416
# 'record_fixed_bytes_per_session': 800
# 'sensor_cooler_status': 2
# 'sensor_mode': 1
# 'sensor_temperature': -20.0
# 'subarray_hpos': 0
# 'subarray_hsize': 4096
# 'subarray_mode': 1
# 'subarray_vpos': 0
# 'subarray_vsize': 2304
# 'system_alive': 2
# 'time_stamp_producer': 5
# 'timing_cyclic_trigger_period': 0.0
# 'timing_exposure': 3
# 'timing_global_exposure_delay': 2.88e-05
# 'timing_invalid_exposure_period': 2.88e-05
# 'timing_min_trigger_blanking': 0.0
# 'timing_min_trigger_interval': 0.0564984
# 'timing_readout_time': 0.0564984
# 'trigger_active': 1
# 'trigger_connector': 2
# 'trigger_delay': 0.0
# 'trigger_global_exposure': 3
# 'trigger_mode': 1
# 'trigger_polarity': 1
# 'trigger_source': 1
# 'trigger_times': 1)
# frame_timings || TAcqTimings(exposure=0.0082944, frame_period=0.0564984)
# roi_limits || (TAxisROILimit(min=4, max=4096, pstep=4, sstep=4, maxbin=4), TAxisROILimit(min=4, max=2304, pstep=4, sstep=4, maxbin=4))
# readout_time || 0.0564984
# acq_status || unstable
# transfer_info || (-1, 0)
# frame_period || 0.0564984
# ===info==
# cls || DCAMCamera
# conn || 0
# detector_size || (4096, 2304)
# frame_info_fields || ['frame_index', 'framestamp', 'timestamp_us', 'camerastamp', 'position_left', 'position_top', 'pixeltype']
# device_info || TDeviceInfo(vendor='Hamamatsu', model='C15550-20UP', serial_number='S/N: 000352', camera_version='1.04')
# all_trigger_modes || ['int', 'ext', 'software', 'master_pulse']
# all_readout_speeds || ['slow', 'fast']
# 1
# 1
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    cam.set_trigger_mode("ext")
    attr = cam.ca["trigger_source"]
    print(cam.get_device_variable("camera_attributes")["trigger_mode"]) # 也可以用 get_device_variable 来获得 trigger_mode 的值
    print(attr.get_value())
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# 2
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    # cam.set_trigger_mode("ext")
    # cam.cav[]
    attr = cam.ca["trigger_source"]
    print(cam.get_device_variable("camera_attributes")["trigger_mode"]) # 也可以用 get_device_variable 来获得 trigger_mode 的值
    print(attr.get_value())
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# 1
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    # cam.set_trigger_mode("ext")
    cam.cav["trigger_source"] = 2
    attr = cam.ca["trigger_source"]
    print(cam.get_device_variable("camera_attributes")["trigger_mode"]) # 也可以用 get_device_variable 来获得 trigger_mode 的值
    print(attr.get_value())
    print(cam.cav["trigger_mode"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# 2
# 1
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    # cam.set_trigger_mode("ext")
    cam.cav["trigger_source"] = 2
    attr = cam.ca["trigger_source"]
    print(cam.get_device_variable("camera_attributes")["trigger_mode"]) # 也可以用 get_device_variable 来获得 trigger_mode 的值
    print(attr.get_value())
    print(cam.cav["trigger_source"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# 1
# 2
# 2
# NORMAL
# (False, 0.0)
# <class 'tuple'>

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    # cam.set_trigger_mode("ext")
    cam.cav["trigger_mode"] = 2
    attr = cam.ca["trigger_source"]
    print(cam.get_device_variable("camera_attributes")["trigger_mode"]) # 也可以用 get_device_variable 来获得 trigger_mode 的值
    print(attr.get_value())
    print(cam.cav["trigger_source"])
    print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    print(type(cam.get_ext_trigger_parameters()))
# Out:
# ---------------------------------------------------------------------------
# DCAMLibError                              Traceback (most recent call last)
# File c:\Users\admin\Documents\camera\camera\hmmt_info.py:51
#      48     for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
#      49     ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
#      50 # cam.set_trigger_mode("ext")
# ---> 51 cam.cav["trigger_mode"] = 2
#      52 attr = cam.ca["trigger_source"]
#      53 print(cam.get_device_variable("camera_attributes")["trigger_mode"]) # 也可以用 get_device_variable 来获得 trigger_mode 的值
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\utils\dictionary.py:1463, in ItemAccessor.__setitem__(self, name, value)
#    1461 name=self._norm_name(name)
#    1462 if self.setter is not None:
# -> 1463     return self.setter(name, value)
#    1464 raise NotImplementedError("setter is not specified")
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\DCAM\DCAM.py:264, in DCAMCamera.set_attribute_value(self, name, value, error_on_missing)
#     258 def set_attribute_value(self, name, value, error_on_missing=True):  # pylint: disable=arguments-differ
#     259     """
#     260     Set value of an attribute with the given name.
#     261
#     262     If the value doesn't exist or can not be written and ``error_on_missing==True``, raise error; otherwise, do nothing.
#     263     """
# --> 264     return super().set_attribute_value(name,value,error_on_missing=error_on_missing)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\interface\camera.py:1073, in IAttributeCamera.set_attribute_value(self, name, value, error_on_missing, **kwargs)
#    1071     return self.set_all_attribute_values(value,root=name,**kwargs)
#    1072 if attr is not None:
# -> 1073     attr.set_value(value,**kwargs)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\DCAM\DCAM.py:140, in DCAMAttribute.set_value(self, value)
#     138 def set_value(self, value):
#     139     """Set attribute value"""
# --> 140     return lib.dcamprop_setgetvalue(self.handle,self.pid,value)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\DCAM\dcamapi4_lib.py:226, in DCAMLib.dcamprop_setgetvalue(self, hdcam, iProp, fValue, option)
#     225 def dcamprop_setgetvalue(self, hdcam, iProp, fValue, option=0):
# --> 226     return self.dcamprop_setgetvalue_lib(hdcam,iProp,fValue,option)
#
# File <string>:1, in <lambda>(h, iProp, pValue, option)
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\core\utils\ctypes_wrap.py:276, in CFunctionWrapper.wrap_annotated.<locals>.wrapped_func(*vargs, **kwargs)
#     274         return a
#     275 call_args=[_to_call_arg(n,t,a) for (n,t,a) in zip(argnames,prep_argtypes,func_args)]
# --> 276 retval=func(*call_args)
#     277 res=self._convert_results(rvals or [None],dict(zip(argnames,func_args)),retval,kwargs,rconv)
#     278 if (not self.tuple_single_retval) and len(res)==0:
#
# File e:\Anaconda\envs\camera\Lib\site-packages\pylablib\devices\DCAM\dcamapi4_lib.py:44, in errcheck.<locals>.errchecker(result, func, arguments)
#      42     code=result
#      43 if code<0 and code not in passing: # positive codes are always success
# ---> 44     raise DCAMLibError(func.__name__,code)
#
# DCAMLibError: function 'dcamprop_setgetvalue' raised error -2147481592 (DCAMERR_INVALIDPARAM)

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    # cam.set_trigger_mode("ext")
    # cam.cav["trigger_mode"] = 
    # attr = cam.ca["trigger_source"]
    # print(cam.get_device_variable("camera_attributes")["trigger_mode"]) # 也可以用 get_device_variable 来获得 trigger_mode 的值
    # print(attr.get_value())
    # print(cam.cav["trigger_source"])
    # print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    # print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    # print(type(cam.get_ext_trigger_parameters()))
    for e in cam.attributes: print(e)
# Out:
# sensor_mode
# readout_speed
# readout_direction
# colortype
# bit_per_channel
# trigger_source
# trigger_mode
# trigger_active
# trigger_global_exposure
# trigger_polarity
# trigger_connector
# trigger_times
# trigger_delay
# sensor_temperature
# sensor_cooler_status
# exposure_time
# defect_correct_mode
# hot_pixel_correct_level
# binning
# subarray_hpos
# subarray_hsize
# subarray_vpos
# subarray_vsize
# subarray_mode
# capture_mode
# intensity_lut_mode
# intensity_lut_page
# timing_readout_time
# timing_cyclic_trigger_period
# timing_min_trigger_blanking
# timing_min_trigger_interval
# timing_global_exposure_delay
# timing_exposure
# timing_invalid_exposure_period
# internal_frame_rate
# internal_frame_interval
# internal_line_speed
# internal_line_interval
# framebundle_mode
# framebundle_number
# framebundle_rowbytes
# framebundle_frame_step_bytes
# image_width
# image_height
# image_rowbytes
# image_framebytes
# image_top_offset_bytes
# image_pixel_type
# image_camera_stamp
# buffer_rowbytes
# buffer_framebytes
# buffer_top_offset_bytes
# buffer_pixel_type
# record_fixed_bytes_per_file
# record_fixed_bytes_per_session
# record_fixed_bytes_per_frame
# number_of_output_trigger_connector
# output_trigger_source[0]
# output_trigger_polarity[0]
# output_trigger_active[0]
# output_trigger_delay[0]
# output_trigger_period[0]
# output_trigger_kind[0]
# output_trigger_pre_hsync_count
# master_pulse_mode
# master_pulse_trigger_source
# master_pulse_interval
# master_pulse_burst_times
# system_alive
# conversion_factor_coeff
# conversion_factor_offset
# image_detector_pixel_width
# image_detector_pixel_height
# image_detector_pixel_num_horz
# image_detector_pixel_num_vert
# time_stamp_producer
# frame_stamp_producer

# %%
import pylablib as pll
from pylablib.devices import DCAM # gives error if dll is not found. The dll is by default in system32 folder and automatically found. if not, then use code `pll.par["devices/dlls/dcamapi"] = "path/to/dlls"`
with DCAM.DCAMCamera() as cam:
    # cam.set_roi(0,128,0,128)
    # images = cam.grab(10)
    if False:
        print(cam.acquisition_in_progress()) # 返回 True/False. docstring: Check if acquisition is in progress
        ## cam.apply_settings() # takes a key-val setting dict
        assert cam.attributes == cam.get_all_attributes() # 这两个字典是完全相同的，seems not pythonic, might prefer the shorter code
        attrDict = cam.attributes # 方便 close cam 后查看
        for e in list(cam.attributes.items())[:3]: print(e) # preview 前 3 个特性。min/max 等有用数值给出，但是 value 不给出
        print(cam.ca["exposure_time"]) # 等价于 cam.get_attribute("exposure_time")。给出一个 DCAMAttribute （e.g. exposure_time）, 适用于看 min/max，但是不能看值（用 cav 看）
        attr = cam.ca["exposure_time"] # 上面的 attribute 可以直接作为对象
        print( # 给出一些有用的对象的属性。attr.update_limits() 有时也是有用的，见 pylablib docstring。
            attr.get_value(), # 也可以用后面的 cav 方法获得
            attr.min, 
            attr.max,
            attr.readable,
            attr.writable,
            attr.step, # 值可变的最小单位
            attr.unit, # not sure what this is 
            attr.values, # not sure what it does, 返回列表
            ) 
        print(cam.cav["exposure_time"]) # 等价于 cam.get_attribute_value("exposure_time")。给出一个 DCAMAttribute（e.g. exposure_time）的 value
        ##  cam.clear_acquisition() # docstring: Clear the acquisition settings. 包括清空 buffer。在 pylablib demo 代码中没有出现过，貌似可以作为衣蛾 sanity check 函数
        ## cam.close() # the good'ol close. 用 with 语句时完全用不着
        ## cam.dcamwait # Obscure stuff, Idk what it is. It returns `CDCAMWAIT_OPEN(supportevent=14103, hwait=2574656206000)`. BTW This is not a method, it's type is CDCAMWAIT_OPEN, whatever it means.
        ## cam.dv # obscure stuff. it's an "ItemAccessor" including getter/setter/deleter
        print(cam.get_acquisition_parameters()) # self-evident, but returns None by default, not sure what it includes yet
        for e in list(cam.get_all_attribute_values(enum_as_str=True).items())[:3]: print(e) # cam.cav 全选版本， 返回一个字典, preview 前 3 个
        ## cam.get_all_attributes() # 等价于前述的 cam.attributes
        print(cam.get_all_readout_speeds()) # 返回一个 list： ['slow', 'fast']
        print(cam.get_all_trigger_modes()) # 返回一个 list： ['int', 'ext', 'software', 'master_pulse']
        ## print(cam.get_attribute("exposure_time")) # 等价于之前的 cam.ca
        ## print(cam.get_attribute_value("exposure_time")) # 等价于之前的 cam.cav。 显然， 本行和上一行的方法都是常用的， 因此有 ca， cav 这样的简写形式. cam.get_attribute_value 的唯一好处是， 在 attribute 有字符串数值时，可以用 enum_as_str=True 来返回字符串， 这一点 cam.cav 做不到
        print(cam.get_data_dimensions()) # 返回一个 tuple， 默认为 (2304, 4096)， 会随着 roi 的设定而变化. c.f. cam.get_detector_size
        print(cam.get_defect_correct_mode()) # 默认返回 True， 貌似会实时 interpolate 不好的像素，可能对 readout speed 有影响
        print(cam.get_detector_size()) # 返回 tuple (4096, 2304)，永远不变。 c.f. cam.get_data_dimensions
        print(cam.get_device_info()) # brand, S/N, etc.
        ## all possible outputs of cam.get_devices_variable():
        print(cam._device_vars.keys())  # cam.get_devices_variable() 接受的 key 来自于弱私有字典 _device_vars. 其中只有三个 keys。每个 key 对应的 val 又是一个字典。以下 每个。 以下 print 这三个字典的所有 key||val 内容， 也就是所谓的 device variables。这些 variables 有些和 cam.get_all_attribute_values 的 key， val 是重合的, 比如 "exposure_time"。但有些只有 key 重合， 比如这里的 trigger_mode 是 int， 而 cam.get_all_attribute_values() 给出的 trigger_mode 是 NORMAL
        print("===settings==")
        for e in cam._device_vars["settings"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===status==")
        for e in cam._device_vars["status"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        print("===info==")
        for e in cam._device_vars["info"].items(): print(e[0], "||", cam.get_device_variable(e[0]))
        ## print(cam.get_exposure()) # 完全等价于 cam.cav["exposure_time"] 以及 cam.get_device_variable("exposure")
    # cam.set_trigger_mode("ext")
    # cam.cav["trigger_mode"] = 
    # attr = cam.ca["trigger_source"]
    # print(cam.get_device_variable("camera_attributes")["trigger_mode"]) # 也可以用 get_device_variable 来获得 trigger_mode 的值
    # print(attr.get_value())
    # print(cam.cav["trigger_source"])
    # print(cam.get_attribute_value("trigger_mode", enum_as_str=True))
    # print(cam.get_ext_trigger_parameters()) # 返回 ext trig 的 (<inversion>, <delay>) tuple, 
    # print(type(cam.get_ext_trigger_parameters()))
    for e in cam.attributes.items(): print(e)
# Out:
# ('sensor_mode', DCAMAttribute(name='SENSOR MODE', kind=enum, id=4194832, min=1, max=18, unit=0))
# ('readout_speed', DCAMAttribute(name='READOUT SPEED', kind=int, id=4194576, min=1, max=2, unit=0))
# ('readout_direction', DCAMAttribute(name='READOUT DIRECTION', kind=enum, id=4194608, min=1, max=1, unit=0))
# ('colortype', DCAMAttribute(name='COLORTYPE', kind=enum, id=4325664, min=1, max=1, unit=0))
# ('bit_per_channel', DCAMAttribute(name='BIT PER CHANNEL', kind=int, id=4325680, min=12, max=16, unit=0))
# ('trigger_source', DCAMAttribute(name='TRIGGER SOURCE', kind=enum, id=1048848, min=1, max=4, unit=0))
# ('trigger_mode', DCAMAttribute(name='TRIGGER MODE', kind=enum, id=1049104, min=1, max=6, unit=0))
# ('trigger_active', DCAMAttribute(name='TRIGGER ACTIVE', kind=enum, id=1048864, min=1, max=3, unit=0))
# ('trigger_global_exposure', DCAMAttribute(name='TRIGGER GLOBAL EXPOSURE', kind=enum, id=2032384, min=3, max=5, unit=0))
# ('trigger_polarity', DCAMAttribute(name='TRIGGER POLARITY', kind=enum, id=1049120, min=1, max=2, unit=0))
# ('trigger_connector', DCAMAttribute(name='TRIGGER CONNECTOR', kind=enum, id=1049136, min=2, max=2, unit=0))
# ('trigger_times', DCAMAttribute(name='TRIGGER TIMES', kind=int, id=1049152, min=1, max=10000, unit=0))
# ('trigger_delay', DCAMAttribute(name='TRIGGER DELAY', kind=float, id=1049184, min=0.0, max=10.0, unit=1))
# ('sensor_temperature', DCAMAttribute(name='SENSOR TEMPERATURE', kind=float, id=2097936, min=-50.0, max=100.0, unit=2))
# ('sensor_cooler_status', DCAMAttribute(name='SENSOR COOLER STATUS', kind=enum, id=2097984, min=1, max=3, unit=0))
# ('exposure_time', DCAMAttribute(name='EXPOSURE TIME', kind=float, id=2031888, min=7.2e-06, max=1800.0, unit=1))
# ('defect_correct_mode', DCAMAttribute(name='DEFECT CORRECT MODE', kind=enum, id=4653072, min=1, max=2, unit=0))
# ('hot_pixel_correct_level', DCAMAttribute(name='HOT PIXEL CORRECT LEVEL', kind=enum, id=4653104, min=1, max=3, unit=0))
# ('binning', DCAMAttribute(name='BINNING', kind=enum, id=4198672, min=1, max=4, unit=0))
# ('subarray_hpos', DCAMAttribute(name='SUBARRAY HPOS', kind=int, id=4202768, min=0, max=4092, unit=0))
# ('subarray_hsize', DCAMAttribute(name='SUBARRAY HSIZE', kind=int, id=4202784, min=4, max=4096, unit=0))
# ('subarray_vpos', DCAMAttribute(name='SUBARRAY VPOS', kind=int, id=4202800, min=0, max=2300, unit=0))
# ('subarray_vsize', DCAMAttribute(name='SUBARRAY VSIZE', kind=int, id=4202816, min=4, max=2304, unit=0))
# ('subarray_mode', DCAMAttribute(name='SUBARRAY MODE', kind=enum, id=4202832, min=1, max=2, unit=0))
# ('capture_mode', DCAMAttribute(name='CAPTURE MODE', kind=enum, id=3671056, min=1, max=1, unit=0))
# ('intensity_lut_mode', DCAMAttribute(name='INTENSITY LUT MODE', kind=enum, id=3671312, min=1, max=2, unit=0))
# ('intensity_lut_page', DCAMAttribute(name='INTENSITY LUT PAGE', kind=enum, id=3671328, min=1, max=1, unit=0))
# ('timing_readout_time', DCAMAttribute(name='TIMING READOUT TIME', kind=float, id=4206608, min=0.0, max=0.0, unit=1))
# ('timing_cyclic_trigger_period', DCAMAttribute(name='TIMING CYCLIC TRIGGER PERIOD', kind=float, id=4206624, min=0.0, max=0.0, unit=1))
# ('timing_min_trigger_blanking', DCAMAttribute(name='TIMING MIN TRIGGER BLANKING', kind=float, id=4206640, min=0.0, max=0.0, unit=1))
# ('timing_min_trigger_interval', DCAMAttribute(name='TIMING MIN TRIGGER INTERVAL', kind=float, id=4206672, min=0.0, max=0.0, unit=1))
# ('timing_global_exposure_delay', DCAMAttribute(name='TIMING GLOBAL EXPOSURE DELAY', kind=float, id=4206736, min=0.0, max=0.008344800000000001, unit=1))
# ('timing_exposure', DCAMAttribute(name='TIMING EXPOSURE', kind=enum, id=4206688, min=3, max=3, unit=0))
# ('timing_invalid_exposure_period', DCAMAttribute(name='TIMING INVALID EXPOSURE PERIOD', kind=float, id=4206704, min=0.0, max=2.88e-05, unit=1))
# ('internal_frame_rate', DCAMAttribute(name='INTERNAL FRAME RATE', kind=float, id=4208656, min=0.0005555555555555556, max=17.69961627231922, unit=5))
# ('internal_frame_interval', DCAMAttribute(name='INTERNAL FRAME INTERVAL', kind=float, id=4208672, min=0.0564984, max=1800.0, unit=1))
# ('internal_line_speed', DCAMAttribute(name='INTERNAL LINE SPEED', kind=float, id=4208704, min=0.638888888888889, max=0.638888888888889, unit=4))
# ('internal_line_interval', DCAMAttribute(name='INTERNAL LINE INTERVAL', kind=float, id=4208720, min=7.2e-06, max=7.2e-06, unit=1))
# ('framebundle_mode', DCAMAttribute(name='FRAMEBUNDLE MODE', kind=enum, id=4329488, min=1, max=2, unit=0))
# ('framebundle_number', DCAMAttribute(name='FRAMEBUNDLE NUMBER', kind=int, id=4329504, min=2, max=2, unit=0))
# ('framebundle_rowbytes', DCAMAttribute(name='FRAMEBUNDLE ROWBYTES', kind=int, id=4329520, min=8192, max=8192, unit=0))
# ('framebundle_frame_step_bytes', DCAMAttribute(name='FRAMEBUNDLE FRAME STEP BYTES', kind=int, id=4329536, min=18874368, max=18874368, unit=0))
# ('image_width', DCAMAttribute(name='IMAGE WIDTH', kind=int, id=4325904, min=4, max=4096, unit=0))
# ('image_height', DCAMAttribute(name='IMAGE HEIGHT', kind=int, id=4325920, min=4, max=2304, unit=0))
# ('image_rowbytes', DCAMAttribute(name='IMAGE ROWBYTES', kind=int, id=4325936, min=2, max=8192, unit=0))
# ('image_framebytes', DCAMAttribute(name='IMAGE FRAMEBYTES', kind=int, id=4325952, min=2, max=18874368, unit=0))
# ('image_top_offset_bytes', DCAMAttribute(name='IMAGE TOP OFFSET BYTES', kind=int, id=4325968, min=0, max=0, unit=0))
# ('image_pixel_type', DCAMAttribute(name='IMAGE PIXEL TYPE', kind=enum, id=4326000, min=1, max=3, unit=0))
# ('image_camera_stamp', DCAMAttribute(name='IMAGE CAMERA STAMP', kind=int, id=4326144, min=0, max=65535, unit=0))
# ('buffer_rowbytes', DCAMAttribute(name='BUFFER ROWBYTES', kind=int, id=4326192, min=2, max=8192, unit=0))
# ('buffer_framebytes', DCAMAttribute(name='BUFFER FRAMEBYTES', kind=int, id=4326208, min=2, max=18874368, unit=0))
# ('buffer_top_offset_bytes', DCAMAttribute(name='BUFFER TOP OFFSET BYTES', kind=int, id=4326224, min=0, max=0, unit=0))
# ('buffer_pixel_type', DCAMAttribute(name='BUFFER PIXEL TYPE', kind=enum, id=4326240, min=1, max=3, unit=0))
# ('record_fixed_bytes_per_file', DCAMAttribute(name='RECORD FIXED BYTES PER FILE', kind=int, id=4326416, min=256, max=256, unit=0))
# ('record_fixed_bytes_per_session', DCAMAttribute(name='RECORD FIXED BYTES PER SESSION', kind=int, id=4326432, min=0, max=1016, unit=0))
# ('record_fixed_bytes_per_frame', DCAMAttribute(name='RECORD FIXED BYTES PER FRAME', kind=int, id=4326448, min=0, max=18874416, unit=0))
# ('number_of_output_trigger_connector', DCAMAttribute(name='NUMBER OF OUTPUT TRIGGER CONNECTOR', kind=int, id=1835024, min=3, max=3, unit=0))
# ('output_trigger_source[0]', DCAMAttribute(name='OUTPUT TRIGGER SOURCE[0]', kind=enum, id=1835280, min=2, max=6, unit=0))
# ('output_trigger_polarity[0]', DCAMAttribute(name='OUTPUT TRIGGER POLARITY[0]', kind=enum, id=1835296, min=1, max=2, unit=0))
# ('output_trigger_active[0]', DCAMAttribute(name='OUTPUT TRIGGER ACTIVE[0]', kind=enum, id=1835312, min=1, max=1, unit=0))
# ('output_trigger_delay[0]', DCAMAttribute(name='OUTPUT TRIGGER DELAY[0]', kind=float, id=1835328, min=0.0, max=10.0, unit=1))
# ('output_trigger_period[0]', DCAMAttribute(name='OUTPUT TRIGGER PERIOD[0]', kind=float, id=1835344, min=1e-06, max=10.0, unit=1))
# ('output_trigger_kind[0]', DCAMAttribute(name='OUTPUT TRIGGER KIND[0]', kind=enum, id=1835360, min=1, max=6, unit=0))
# ('output_trigger_pre_hsync_count', DCAMAttribute(name='OUTPUT TRIGGER PRE HSYNC COUNT', kind=int, id=1835408, min=0, max=4607, unit=0))
# ('master_pulse_mode', DCAMAttribute(name='MASTER PULSE MODE', kind=enum, id=1966112, min=1, max=3, unit=0))
# ('master_pulse_trigger_source', DCAMAttribute(name='MASTER PULSE TRIGGER SOURCE', kind=enum, id=1966128, min=1, max=2, unit=0))
# ('master_pulse_interval', DCAMAttribute(name='MASTER PULSE INTERVAL', kind=float, id=1966144, min=4.9999999999999996e-06, max=10.0, unit=1))
# ('master_pulse_burst_times', DCAMAttribute(name='MASTER PULSE BURST TIMES', kind=int, id=1966160, min=1, max=65535, unit=0))
# ('system_alive', DCAMAttribute(name='SYSTEM ALIVE', kind=enum, id=16711696, min=1, max=2, unit=0))
# ('conversion_factor_coeff', DCAMAttribute(name='CONVERSION FACTOR COEFF', kind=float, id=16769040, min=0.0, max=255.99, unit=0))
# ('conversion_factor_offset', DCAMAttribute(name='CONVERSION FACTOR OFFSET', kind=float, id=16769056, min=-65535.0, max=65535.0, unit=0))
# ('image_detector_pixel_width', DCAMAttribute(name='IMAGE DETECTOR PIXEL WIDTH', kind=float, id=4327440, min=4.6000000000000005, max=4.6000000000000005, unit=7))
# ('image_detector_pixel_height', DCAMAttribute(name='IMAGE DETECTOR PIXEL HEIGHT', kind=float, id=4327456, min=4.6000000000000005, max=4.6000000000000005, unit=7))
# ('image_detector_pixel_num_horz', DCAMAttribute(name='IMAGE DETECTOR PIXEL NUM HORZ', kind=int, id=4327472, min=4096, max=4096, unit=0))
# ('image_detector_pixel_num_vert', DCAMAttribute(name='IMAGE DETECTOR PIXEL NUM VERT', kind=int, id=4327488, min=2304, max=2304, unit=0))
# ('time_stamp_producer', DCAMAttribute(name='TIME STAMP PRODUCER', kind=enum, id=4262416, min=5, max=5, unit=0))
# ('frame_stamp_producer', DCAMAttribute(name='FRAME STAMP PRODUCER', kind=enum, id=4262432, min=5, max=5, unit=0))

# %%
attrDict[sensor_mode]["kind"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 attrDict[sensor_mode]["kind"]
#
# NameError: name 'sensor_mode' is not defined
